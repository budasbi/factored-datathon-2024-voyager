# %% [markdown]
# <p style='text-align: right;'><i>Aug 12 - 25, 2024 </i> </p>

# %% [markdown]
# <h1 style="background-color:orange;"></h1>

# %% [markdown]
# <h1 style='text-align: center;'> Voyager Team Datathon 2024 </h1>
#
# <h3 style='text-align: center;'> <i>PART I: EDA to narrow the scope </i> </h3>
#
# <h5 style='text-align: center;'> <i>Our data journey</i> </h5>

# %% [markdown]
# <h1 style="background-color:orange;"></h1>

# %% [markdown]
# <div style="background-color:LightGray;"><p style='text-align: center;'><align = center>Participants: <i>Oscar Sierra, David Mercado, Rodrigo Quezada </i></p></div>

# %% [markdown]
# ***

# %% [markdown]
# <h2 style='text-align: center;'><font color=blue> What is data telling us ? <color></h2>

# %% [markdown]
# ***

# %% [markdown]
# <h2 style="background-color:Orange;"><font color=white>1. Intro<color></h2>

# %% [markdown]
# While would like to follow the CRISP-DM methodology it was not possible as the challenge for this Datathon does not start with specific objective or problem to solve rather starts at data available.
#
# Thus key goal is :
#
# <h3 style='text-align: center;'><b> "Uncover critical insights from global events that allow for early intervention and strategic planning, ultimately helping businesses and organizations navigate complex and volatile environments." </h3></p>
#
# Also stated by Factored as:
#
# "You will dive deep into the vast and dynamic dataset provided by the Global Database of Events, Language, and Tone GDELT . This year, we're presenting two challenges, designed to test your data skills and creativity."

# %% [markdown]
# .

# %% [markdown]
# ### Last but not least we are using the defined Evaluation Criteria for our solution
#
#
# 1. Overall project rationale and documentation
# 2. Data Engineering: How are you dealing with the Extraction
# and Transformation of the data
# 3. Machine Learning: Model selection, optimization,
# implementation and tracking
# 4. Data Analytics: Data Quality and Providing relevant insights
# from the solution
# 5. Software Engineering: Backend, Frontend and Deployment.

# %% [markdown]
# #### We will work through an iterative and incremental process

# %% [markdown]
# <h2 style="background-color:Orange;"><font color=white>2. Problem <color></h2>

# %% [markdown]
# Our first step is to set the **Data Pipeline** to correctly ingest data with the right quality so it is delivered analysis.
#
# This step is also refered to as Data Engineering or Data Collection and by Google as Data Prep.
#
# Thus our first step gathers a sample from which to begin the Data Understanding and per inferene also the Business
# Understanding.

# %% [markdown]
#  ### Imports for data set pull
#
# > Getting started

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyarrow

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Several iterations have been used to explore and adjust per the findings and below is an example of code used to extract files for early EDA stage shared below
#
#     <h3> The final EDA will be presented towards our solution. </h3>
#
# </div>

# %% [markdown]
# ***

# %%
# At one point in time installing to use this library

# pip install boto3

# %%
#Code used at one point in time for early EDA


#import boto3
#import os
#s3_bucket_name = 'factored-datathon-2024-voyager-tests'  
#s3_region = 'us-east-1'   
#aws_key_id = 'AKIA3FLD2PY65KIZWW65'
#aws_secret_key = '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'

#local_dir =r'C:\Users\dslab\Downloads\Datathon_from_S3_8_17'

# %%
# Code used at one point in time for early EDA

#session = boto3.Session(aws_access_key_id=aws_key_id, aws_secret_access_key=aws_secret_key)
#s3 = session.client('s3', region_name=s3_region)
#bucket_name = s3_bucket_name

#def download_s3_bucket(bucket_name, local_dir):
#    paginator = s3.get_paginator('list_objects_v2')
#   for page in paginator.paginate(Bucket=bucket_name):
#        for obj in page.get('Contents', []):
#            # Obtener el key (ruta del archivo en S3)
#            key = obj['Key']
#            # Crear la ruta local
#            local_path = os.path.join(local_dir, key)
#            # Crear los directorios si no existen
#            if not os.path.exists(os.path.dirname(local_path)):
#                os.makedirs(os.path.dirname(local_path))
#            # Descargar el archivo
#            s3.download_file(bucket_name, key, local_path)
#            print(f'Descargado: {key} a {local_path}')


#download_s3_bucket(bucket_name, local_dir)

# %% [markdown]
# ## Extract all event files parsed for day 8-8-2024

# %%
# Extracting events datasets for a single day

e00 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00000-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e01 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00001-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e02 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00002-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e03 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00003-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e04 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00004-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e05 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00005-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e06 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00006-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e07 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00007-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e08 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00008-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e09 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00009-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e10 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00010-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e11 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00011-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"
e12 = "/Users/dslab/Downloads/drive-download-20240821T002028Z-001/part-00012-c575e648-1634-495f-8af3-266ee7c5e9d9.c000.snappy.parquet"

eds00 = pd.read_parquet(e00, engine='pyarrow')
eds01 = pd.read_parquet(e01, engine='pyarrow')
eds02 = pd.read_parquet(e02, engine='pyarrow')
eds03 = pd.read_parquet(e03, engine='pyarrow')
eds04 = pd.read_parquet(e04, engine='pyarrow')
eds05 = pd.read_parquet(e05, engine='pyarrow')
eds06 = pd.read_parquet(e06, engine='pyarrow')
eds07 = pd.read_parquet(e07, engine='pyarrow')
eds08 = pd.read_parquet(e08, engine='pyarrow')
eds09 = pd.read_parquet(e09, engine='pyarrow')
eds10 = pd.read_parquet(e10, engine='pyarrow')
eds11 = pd.read_parquet(e11, engine='pyarrow')
eds12 = pd.read_parquet(e12, engine='pyarrow')

# %% [markdown]
# ### Confirm data and merge them all into a single dataset

# %%
# Check columns

eds00.shape
# Out:
# (10771, 61)

# %%
print("Expected dataset merged outcome:", eds00.shape[0]+eds01.shape[0]+eds02.shape[0]+eds03.shape[0]+eds04.shape[0]+eds05.shape[0]+eds06.shape[0]+eds07.shape[0]+eds08.shape[0]+eds09.shape[0]+eds10.shape[0]+eds11.shape[0]+eds12.shape[0])
# Out:
# Expected dataset merged outcome: 135253

# %%
# Merging into a single dataset for events

eds = pd.concat([eds00, eds01, eds02, eds03, eds04, eds05, eds06, eds07, eds08, eds09, eds10, eds11, eds12], ignore_index=True)

eds.shape
# Out:
# (135253, 61)

# %% [markdown]
# ### Events Data Profiling
#
# <br/>
#
# > 1. Dimension shape
#
# > 2. Check head and tail
#
# > 3. Review data types, column names, and identify missing data
#
# > 4. Review statistical data for numerical variables
#
# > 5. Determine overall data quality

# %%
eds.shape
# Out:
# (135253, 61)

# %%
eds.head(3)
# Out:
#    global_event_id     sqldate  month_year  year  fraction_date actor_1_code  \
# 0       1191508312  2023-08-09      202308  2023         2023.6         None
# 1       1191508313  2023-08-09      202308  2023         2023.6          BRA
# 2       1191508314  2023-08-09      202308  2023         2023.6          FJI
#
#   actor_1_name actor_1_country_Code actor_1_known_group_code  \
# 0         None                 None                     None
# 1       BRAZIL                  BRA                     None
# 2       FIJIAN                  FJI                     None
#
#   actor_1_ethnic_code  ... action_geo_country_code action_geo_adm1_code  \
# 0                None  ...                      FR                   FR
# 1                None  ...                      US                   US
# 2                None  ...                      FJ                   FJ
#
#   action_geo_lat action_geo_long action_geo_feature_id  \
# 0      46.000000          2.0000                    FR
# 1      39.828175        -98.5795                    US
# 2     -18.000000        178.0000                    FJ
#
#                                           source_url  \
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...
#
#   actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 0                       None                        None
# 1                       None                        None
# 2                       None                          FJ
#
#   actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 0                       None                          FR
# 1                       None                        None
# 2                       None                          FJ
#
# [3 rows x 61 columns]

# %%
eds.tail(3)
# Out:
#         global_event_id     sqldate  month_year  year  fraction_date  \
# 135250       1191708376  2024-08-08      202408  2024      2024.5973
# 135251       1191708377  2024-08-08      202408  2024      2024.5973
# 135252       1191708378  2024-08-08      202408  2024      2024.5973
#
#        actor_1_code actor_1_name actor_1_country_Code  \
# 135250          SCO     SCOTTISH                 None
# 135251          SCO     SCOTTISH                 None
# 135252          SCO     SCOTTISH                 None
#
#        actor_1_known_group_code actor_1_ethnic_code  ...  \
# 135250                     None                 SCO  ...
# 135251                     None                 SCO  ...
# 135252                     None                 SCO  ...
#
#        action_geo_country_code action_geo_adm1_code action_geo_lat  \
# 135250                      US                 USTX        31.1060
# 135251                      UK                 UKW2        55.8333
# 135252                      US                 USTX        31.1060
#
#        action_geo_long action_geo_feature_id  \
# 135250        -97.6475                    TX
# 135251         -4.5000              -2606148
# 135252        -97.6475                    TX
#
#                                             source_url  \
# 135250  https://www.bbc.com/news/articles/clywwzzn14wo
# 135251  https://www.bbc.com/news/articles/clywwzzn14wo
# 135252  https://www.bbc.com/news/articles/clywwzzn14wo
#
#        actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 135250                       None                          TX
# 135251                       None                        None
# 135252                       None                          TX
#
#        actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 135250                       None                        None
# 135251                       None                        None
# 135252                       None                        None
#
# [3 rows x 61 columns]

# %%
eds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135253 entries, 0 to 135252
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   global_event_id              135253 non-null  int32
#  1   sqldate                      135253 non-null  object
#  2   month_year                   135253 non-null  int32
#  3   year                         135253 non-null  int32
#  4   fraction_date                135253 non-null  float64
#  5   actor_1_code                 121754 non-null  object
#  6   actor_1_name                 121754 non-null  object
#  7   actor_1_country_Code         75156 non-null   object
#  8   actor_1_known_group_code     1287 non-null    object
#  9   actor_1_ethnic_code          885 non-null     object
#  10  actor_1_religion_code        1836 non-null    object
#  11  actor_1_religion_2_code      356 non-null     object
#  12  actor_1_type_code            58667 non-null   object
#  13  actor_1_type_2_code          3529 non-null    object
#  14  actor_1_type_3_code          100 non-null     object
#  15  actor_2_code                 95740 non-null   object
#  16  actor_name                   95740 non-null   object
#  17  actor_2_country_code         59489 non-null   object
#  18  actor_2_known_group_code     835 non-null     object
#  19  actor_2_ethnic_code          644 non-null     object
#  20  actor_2_religion_1_code      1500 non-null    object
#  21  actor_2_religion_2_code      258 non-null     object
#  22  actor_2_type_1_code          45649 non-null   object
#  23  actor_2_type_2_code          2404 non-null    object
#  24  actor_2_type_3_code          68 non-null      object
#  25  is_root_event                135253 non-null  int32
#  26  event_code                   135253 non-null  int32
#  27  event_base_code              135253 non-null  int32
#  28  event_root_code              135253 non-null  int32
#  29  quad_class                   135253 non-null  int32
#  30  goldstein_scale              135253 non-null  float64
#  31  num_mentions                 135253 non-null  int32
#  32  num_sources                  135253 non-null  int32
#  33  num_articles                 135253 non-null  int32
#  34  avg_tone                     135253 non-null  float64
#  35  actor_1_geo_type             135253 non-null  int32
#  36  actor_1_geo_fullname         118059 non-null  object
#  37  actor_1_geo_country_code     118091 non-null  object
#  38  actor_1_geo_adm1_code        118091 non-null  object
#  39  actor_1_geo_lat              118059 non-null  float64
#  40  actor_1_geo_long             118072 non-null  float64
#  41  actor_1_geo_feature_id       118091 non-null  object
#  42  actor_2_geo_type             135253 non-null  int32
#  43  actor_2_geo_fullname         92975 non-null   object
#  44  actor_2_geo_country_code     92990 non-null   object
#  45  actor_2_geo_adm1_code        92990 non-null   object
#  46  actor_2_geo_lat              92975 non-null   float64
#  47  actor_2_geo_long             92983 non-null   float64
#  48  actor_2_geo_feature_id       92990 non-null   object
#  49  action_geo_type              135253 non-null  int32
#  50  action_geo_fullname          131186 non-null  object
#  51  action_geo_country_code      131211 non-null  object
#  52  action_geo_adm1_code         131211 non-null  object
#  53  action_geo_lat               131186 non-null  float64
#  54  action_geo_long              131199 non-null  float64
#  55  action_geo_feature_id        131211 non-null  object
#  56  source_url                   135253 non-null  object
#  57  actor_1_geo_feature_id_num   23976 non-null   object
#  58  actor_1_geo_feature_id_text  43985 non-null   object
#  59  actor_2_geo_feature_id_num   17691 non-null   object
#  60  actor_2_geo_feature_id_text  34764 non-null   object
# dtypes: float64(9), int32(14), object(38)
# memory usage: 55.7+ MB

# %%
eds.describe()
# Out:
#        global_event_id     month_year           year  fraction_date  \
# count     1.352530e+05  135253.000000  135253.000000  135253.000000
# mean      1.191608e+09  202407.132182    2023.991379    2024.588108
# std       5.974460e+04      15.443759       0.154439       0.154320
# min       1.191508e+09  201408.000000    2014.000000    2014.605500
# 25%       1.191555e+09  202408.000000    2024.000000    2024.597300
# 50%       1.191609e+09  202408.000000    2024.000000    2024.597300
# 75%       1.191661e+09  202408.000000    2024.000000    2024.597300
# max       1.191708e+09  202408.000000    2024.000000    2024.597300
#
#        is_root_event     event_code  event_base_code  event_root_code  \
# count  135253.000000  135253.000000    135253.000000    135253.000000
# mean        0.605133     101.681094        71.401270         6.957177
# std         0.488824     197.778764        56.243152         5.630334
# min         0.000000      10.000000        10.000000         1.000000
# 25%         0.000000      36.000000        36.000000         3.000000
# 50%         1.000000      46.000000        46.000000         4.000000
# 75%         1.000000     112.000000       111.000000        11.000000
# max         1.000000    1832.000000       203.000000        20.000000
#
#           quad_class  goldstein_scale  ...       avg_tone  actor_1_geo_type  \
# count  135253.000000    135253.000000  ...  135253.000000     135253.000000
# mean        1.838577         0.353476  ...      -2.193628          2.518192
# std         1.146697         4.686513  ...       4.286355          1.511944
# min         1.000000       -10.000000  ...     -30.000000          0.000000
# 25%         1.000000        -2.000000  ...      -5.160391          1.000000
# 50%         1.000000         1.000000  ...      -2.217295          3.000000
# 75%         3.000000         3.400000  ...       0.729927          4.000000
# max         4.000000        10.000000  ...      23.076923          5.000000
#
#        actor_1_geo_lat  actor_1_geo_long  actor_2_geo_type  actor_2_geo_lat  \
# count    118059.000000     118072.000000     135253.000000     92975.000000
# mean         31.466319         -5.576096          1.984932        31.558697
# std          20.845873         78.104669          1.701832        20.586585
# min         -85.622100       -176.533000          0.000000       -85.622100
# 25%          25.083300        -81.717000          0.000000        25.183300
# 50%          35.925500          2.183330          2.000000        35.750000
# 75%          44.239400         42.000000          4.000000        44.239400
# max          79.209300        180.000000          5.000000        78.000000
#
#        actor_2_geo_long  action_geo_type  action_geo_lat  action_geo_long
# count      92983.000000    135253.000000   131186.000000    131199.000000
# mean          -1.821727         2.811139       31.350373        -6.198391
# std           77.148142         1.319632       20.882310        78.603947
# min         -175.000000         0.000000      -85.622100      -176.533000
# 25%          -79.843100         2.000000       25.047800       -82.133200
# 50%            7.533330         3.000000       35.810900         2.000000
# 75%           44.513600         4.000000       43.739400        42.572400
# max          179.367000         5.000000       79.209300       180.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## Extract all count files parsed for day 8-8-2024

# %%
# Extracting events datasets for a single day

c00 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00000-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c01 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00001-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c02 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00002-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c03 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00003-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c04 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00004-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c05 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00005-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c06 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00006-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c07 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00007-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c08 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00008-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c09 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00009-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c10 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00010-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c11 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00011-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c12 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00012-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c13 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00013-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c14 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00014-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c15 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00015-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"
c16 = "/Users/dslab/Downloads/drive-download-20240821T004440Z-001/part-00016-9a927315-769f-4b0f-8c61-0a28efc284cc.c000.snappy.parquet"

cds00 = pd.read_parquet(c00, engine='pyarrow')
cds01 = pd.read_parquet(c01, engine='pyarrow')
cds02 = pd.read_parquet(c02, engine='pyarrow')
cds03 = pd.read_parquet(c03, engine='pyarrow')
cds04 = pd.read_parquet(c04, engine='pyarrow')
cds05 = pd.read_parquet(c05, engine='pyarrow')
cds06 = pd.read_parquet(c06, engine='pyarrow')
cds07 = pd.read_parquet(c07, engine='pyarrow')
cds08 = pd.read_parquet(c08, engine='pyarrow')
cds09 = pd.read_parquet(c09, engine='pyarrow')
cds10 = pd.read_parquet(c10, engine='pyarrow')
cds11 = pd.read_parquet(c11, engine='pyarrow')
cds12 = pd.read_parquet(c12, engine='pyarrow')
cds13 = pd.read_parquet(c13, engine='pyarrow')
cds14 = pd.read_parquet(c14, engine='pyarrow')
cds15 = pd.read_parquet(c15, engine='pyarrow')
cds16 = pd.read_parquet(c16, engine='pyarrow')

# %% [markdown]
# ### Confirm data and merge them all into a single dataset

# %%
# Check columns

cds00.shape
# Out:
# (15867, 14)

# %%
print("Expected dataset merged outcome:", cds00.shape[0]+cds01.shape[0]+cds02.shape[0]+cds03.shape[0]+cds04.shape[0]
      +cds05.shape[0]+cds06.shape[0]+cds07.shape[0]+cds08.shape[0]+cds09.shape[0]+cds10.shape[0]+cds11.shape[0]
      +cds12.shape[0]+cds13.shape[0]+cds14.shape[0]+cds15.shape[0]+cds16.shape[0])
# Out:
# Expected dataset merged outcome: 263475

# %%
# Merging into a single dataset for counts

cds = pd.concat([cds00, cds01, cds02, cds03, cds04, cds05, cds06, cds07, cds08, cds09, cds10, 
                 cds11, cds12, cds13, cds14, cds15, cds16], ignore_index=True)

cds.shape
# Out:
# (263475, 14)

# %% [markdown]
# ### Counts Data Profiling
#
# <br/>
#
# > 1. Dimension shape
#
# > 2. Check head and tail
#
# > 3. Review data types, column names, and identify missing data
#
# > 4. Review statistical data for numerical variables
#
# > 5. Determine overall data quality

# %%
cds.shape
# Out:
# (263475, 14)

# %%
cds.head(3)
# Out:
#    numarts        count_type  number         object_type  geo_type  \
# 0        1  SOC_GENERALCRIME      10                None         1
# 1        1            ARREST     569  attorney Rohrbaugh         2
# 2        1            AFFECT      14                None         4
#
#                  geo_fullname geo_country_code geo_adm1_code  geo_lat  \
# 0                      France               FR            FR  46.0000
# 1         Ohio, United States               US          USOH  40.3736
# 2  Chatra, West Bengal, India               IN          IN28  24.3833
#
#    geo_long geo_feature_id cameo_event_ids                sources  \
# 0    2.0000             FR      1191594214  thedrinksbusiness.com
# 1  -82.7755             OH      1191578820              vindy.com
# 2   87.8500       -2092981      1191534178         indiatimes.com
#
#                                          source_urls
# 0  https://www.thedrinksbusiness.com/2024/08/trus...
# 1  https://www.vindy.com/news/local-news/2024/08/...
# 2  https://timesofindia.indiatimes.com/city/ranch...

# %%
cds.tail(3)
# Out:
#         numarts            count_type  number    object_type  geo_type  \
# 263472      132  CRISISLEX_C07_SAFETY       2       suspects         4
# 263473        1                ARREST      10           None         1
# 263474        1                  KILL     100  demonstrators         1
#
#                  geo_fullname geo_country_code geo_adm1_code    geo_lat  \
# 263472  Vienna, Wien, Austria               AU          AU09  48.200000
# 263473                 Turkey               TU            TU  39.059012
# 263474                 Russia               RS            RS  60.000000
#
#           geo_long geo_feature_id cameo_event_ids  \
# 263472   16.366700       -1995499      1191599076
# 263473   34.911546             TU      1191510538
# 263474  100.000000             RS      1191686984
#
#                                                   sources  \
# 263472  ks95.com;wrmf.com;easy93.com;komonews.com;6abc...
# 263473                                  middleeasteye.net
# 263474                                         sbs.com.au
#
#                                               source_urls
# 263472  https://www.ks95.com/taylor-swift-shows-in-vie...
# 263473  https://www.middleeasteye.net/news/us-zero-tol...
# 263474  https://www.sbs.com.au/news/article/the-leader...

# %%
cds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263475 entries, 0 to 263474
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   numarts           263475 non-null  int32
#  1   count_type        263475 non-null  object
#  2   number            263475 non-null  int64
#  3   object_type       78637 non-null   object
#  4   geo_type          263475 non-null  int32
#  5   geo_fullname      259402 non-null  object
#  6   geo_country_code  259432 non-null  object
#  7   geo_adm1_code     259432 non-null  object
#  8   geo_lat           259402 non-null  float64
#  9   geo_long          259402 non-null  float64
#  10  geo_feature_id    259432 non-null  object
#  11  cameo_event_ids   263475 non-null  object
#  12  sources           263475 non-null  object
#  13  source_urls       263475 non-null  object
# dtypes: float64(2), int32(2), int64(1), object(9)
# memory usage: 26.1+ MB

# %%
cds.describe()
# Out:
#              numarts        number       geo_type        geo_lat  \
# count  263475.000000  2.634750e+05  263475.000000  259402.000000
# mean       20.162896  2.365195e+08       2.143623      34.864865
# std        45.482759  1.751675e+10       1.404659      16.511280
# min         1.000000  1.000000e+00       0.000000     -46.350000
# 25%         1.000000  5.000000e+00       1.000000      31.416700
# 50%         3.000000  2.200000e+01       1.000000      32.000000
# 75%        14.000000  2.000000e+02       4.000000      48.200000
# max       522.000000  1.590724e+12       5.000000      64.016700
#
#             geo_long
# count  259402.000000
# mean       12.630733
# std        60.148982
# min      -175.000000
# 25%        -4.000000
# 50%        34.333300
# 75%        35.509700
# max       180.000000

# %% [markdown]
# ### EDA at the cds (acronym for Counts Data Set) dataset first
#
# #### Assess information gain given our objective to:
# <br/>
#
# > 1. Remove columns or rows that are not needed
#
# > 2. Rename columns
#
# > 3. Address missing data
#
# > 4. Ensure proper formatting
#
# > 5. Sort as needed
#
# > 6. Slice or Group as needed
#
# > 7. Add feature engineering

# %% [markdown]
# ***

# %%
cds.rename(columns={'cameo_event_ids': 'Cameo'}, inplace=True)
                    
cds.head(1)
# Out:
#    numarts        count_type  number object_type  geo_type geo_fullname  \
# 0        1  SOC_GENERALCRIME      10        None         1       France
#
#   geo_country_code geo_adm1_code  geo_lat  geo_long geo_feature_id  \
# 0               FR            FR     46.0       2.0             FR
#
#         Cameo                sources  \
# 0  1191594214  thedrinksbusiness.com
#
#                                          source_urls
# 0  https://www.thedrinksbusiness.com/2024/08/trus...

# %%
cds['Cameo'].value_counts()
# Out:
# Cameo
# 1191509983    373
# 1191509934    345
# 1191522004    317
# 1191520900    252
# 1191509168    235
#              ...
# 1191608626      1
# 1191703782      1
# 1191703992      1
# 1191631557      1
# 1191528198      1
# Name: count, Length: 41556, dtype: int64

# %%
cds.columns
# Out:
# Index(['numarts', 'count_type', 'number', 'object_type', 'geo_type',
#        'geo_fullname', 'geo_country_code', 'geo_adm1_code', 'geo_lat',
#        'geo_long', 'geo_feature_id', 'Cameo', 'sources', 'source_urls'],
#       dtype='object')

# %%
cds['geo_country_code'].value_counts()
# Out:
# geo_country_code
# IS    62872
# US    40591
# UK    34719
# RS    13320
# BG     9205
#       ...
# BT        3
# CV        2
# GK        1
# GA        1
# SC        1
# Name: count, Length: 160, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Interesting as was expecting US to have the highest count and yet it is Israel for this specific date.
# - Also interesting fact that some countries get as little as one record for a single day and given the amount of countries almost one third go without any record for this day.
#
#     <h3> Makes sense that US is within the top 3. </h3>
#
# </div>

# %%
cds['geo_country_code'] = cds['geo_country_code'].str.upper()

# %%
cds.rename(columns={'geo_country_code': 'Country'}, inplace=True)
                    
cds.head(1)
# Out:
#    numarts        count_type  number object_type  geo_type geo_fullname  \
# 0        1  SOC_GENERALCRIME      10        None         1       France
#
#   Country geo_adm1_code  geo_lat  geo_long geo_feature_id       Cameo  \
# 0      FR            FR     46.0       2.0             FR  1191594214
#
#                  sources                                        source_urls
# 0  thedrinksbusiness.com  https://www.thedrinksbusiness.com/2024/08/trus...

# %%
cds.rename(columns={'numarts': 'Articles'}, inplace=True)
                    
cds.head(1)
# Out:
#    Articles        count_type  number object_type  geo_type geo_fullname  \
# 0         1  SOC_GENERALCRIME      10        None         1       France
#
#   Country geo_adm1_code  geo_lat  geo_long geo_feature_id       Cameo  \
# 0      FR            FR     46.0       2.0             FR  1191594214
#
#                  sources                                        source_urls
# 0  thedrinksbusiness.com  https://www.thedrinksbusiness.com/2024/08/trus...

# %%
cds.describe()
# Out:
#             Articles        number       geo_type        geo_lat  \
# count  263475.000000  2.634750e+05  263475.000000  259402.000000
# mean       20.162896  2.365195e+08       2.143623      34.864865
# std        45.482759  1.751675e+10       1.404659      16.511280
# min         1.000000  1.000000e+00       0.000000     -46.350000
# 25%         1.000000  5.000000e+00       1.000000      31.416700
# 50%         3.000000  2.200000e+01       1.000000      32.000000
# 75%        14.000000  2.000000e+02       4.000000      48.200000
# max       522.000000  1.590724e+12       5.000000      64.016700
#
#             geo_long
# count  259402.000000
# mean       12.630733
# std        60.148982
# min      -175.000000
# 25%        -4.000000
# 50%        34.333300
# 75%        35.509700
# max       180.000000

# %%
cds.rename(columns={'count_type': 'Description'}, inplace=True)
                    
cds.head(1)
# Out:
#    Articles       Description  number object_type  geo_type geo_fullname  \
# 0         1  SOC_GENERALCRIME      10        None         1       France
#
#   Country geo_adm1_code  geo_lat  geo_long geo_feature_id       Cameo  \
# 0      FR            FR     46.0       2.0             FR  1191594214
#
#                  sources                                        source_urls
# 0  thedrinksbusiness.com  https://www.thedrinksbusiness.com/2024/08/trus...

# %%
cds.rename(columns={'number': 'Magnitud'}, inplace=True)
                    
cds.head(1)
# Out:
#    Articles       Description  Magnitud object_type  geo_type geo_fullname  \
# 0         1  SOC_GENERALCRIME        10        None         1       France
#
#   Country geo_adm1_code  geo_lat  geo_long geo_feature_id       Cameo  \
# 0      FR            FR     46.0       2.0             FR  1191594214
#
#                  sources                                        source_urls
# 0  thedrinksbusiness.com  https://www.thedrinksbusiness.com/2024/08/trus...

# %%
cds['object_type'].value_counts()
# Out:
# object_type
# Palestinians      5897
# children          3328
# civilians         2931
# suspects          2297
# ions              2292
#                   ...
# half                 1
# NEW ADDITIONS        1
# municipalities       1
# contracts            1
# offerings            1
# Name: count, Length: 1589, dtype: int64

# %%
cds['geo_type'].value_counts()
# Out:
# geo_type
# 1    141708
# 4     80577
# 3     17172
# 2     16872
# 0      4043
# 5      3103
# Name: count, dtype: int64

# %% [markdown]
# *Context*
#
# This field specifies the geographic resolution of the match type and holds
# one of the following values: <br>
# <li>1=COUNTRY (match was at the country level) </li>
# <li>2=USSTATE (match was to a US state)</li>
# <li>3=USCITY (match was to a US city or landmark)</li>
# <li>4=WORLDCITY (match was to a city or landmark outside the US)</li>
# <li>5=WORLDSTATE (match was to an Administrative Division 1 outside the US – roughly equivalent to a US state). </li>

# %%
filtered_geo = cds[cds['geo_type'] == 5]
filtered_geo.head()
# Out:
#      Articles             Description  Magnitud object_type  geo_type  \
# 70          3        SOC_GENERALCRIME        22  protestors         5
# 91          1   CRISISLEX_T02_INJURED        24        None         5
# 97          3  CRISISLEX_CRISISLEXREC        66        None         5
# 166         1   CRISISLEX_T02_INJURED         2        None         5
# 173         1                  ARREST       200        None         5
#
#                         geo_fullname Country geo_adm1_code  geo_lat  geo_long  \
# 70   North Yorkshire, United Kingdom      UK          UKJ7  54.1667     -1.50
# 91               Chin State, Myanmar      BM          BM02  22.0000     93.50
# 97   Buckinghamshire, United Kingdom      UK          UKB9  51.7500     -0.75
# 166            Madhya Pradesh, India      IN          IN35  23.5000     78.50
# 173  Buckinghamshire, United Kingdom      UK          UKB9  51.7500     -0.75
#
#     geo_feature_id       Cameo  \
# 70        -2604430  1191607232
# 91         -412046  1191611305
# 97        -2591191  1191672581
# 166       -2103026  1191679378
# 173       -2591191  1191672276
#
#                                              sources  \
# 70              lbc.co.uk;wn.com;thebusinessdesk.com
# 91                                     irrawaddy.com
# 97   dailymail.co.uk;dailymail.co.uk;dailymail.co.uk
# 166                                     thehindu.com
# 173                                  dailymail.co.uk
#
#                                            source_urls
# 70   https://www.lbc.co.uk/news/drax-power-station-...
# 91   https://www.irrawaddy.com/news/burma/myanmar-m...
# 97   https://www.dailymail.co.uk/news/article-13724...
# 166  https://www.thehindu.com/news/national/madhya-...
# 173  https://www.dailymail.co.uk/news/article-13724...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Interesting finding on row 91 that currently Chin State is at country Myanmar yet displayed as BM since formerly known as Burma.
#
#     <h3> To keep consistency regardless of name changes we need to let go the geo_fullname and geo_code columns. </h3>
#
# </div>

# %%
filtered_geo = cds[cds['geo_type'] == 4]
filtered_geo.head()
# Out:
#     Articles             Description  Magnitud object_type  geo_type  \
# 2          1                  AFFECT        14        None         4
# 4          3  CRISISLEX_CRISISLEXREC        24        None         4
# 8         62                  ARREST         5        None         4
# 18         1    CRISISLEX_C07_SAFETY         2        None         4
# 26        15               DISPLACED   3000000        None         4
#
#                                    geo_fullname Country geo_adm1_code  \
# 2                    Chatra, West Bengal, India      IN          IN28
# 4           Gaza City, Israel (General), Israel      IS          IS00
# 8   Northern Ireland, Craigavon, United Kingdom      UK          UKR8
# 18             Croydon, Croydon, United Kingdom      UK          UKC8
# 26               Gaza, Israel (General), Israel      IS          IS00
#
#     geo_lat  geo_long geo_feature_id       Cameo  \
# 2   24.3833   87.8500       -2092981  1191534178
# 4   31.4167   34.3333        -797156  1191646797
# 8   54.5000   -6.5000       -2604275  1191636930
# 18  51.3833   -0.1000       -2593790  1191621910
# 26  31.4167   34.3333        -797156  1191513159
#
#                                               sources  \
# 2                                      indiatimes.com
# 4                       newarab.com;dw.com;presstv.ir
# 8   newsletter.co.uk;countypress.co.uk;westerntele...
# 18                                          thejc.com
# 26  thehill.com;wsls.com;mymotherlode.com;theweek....
#
#                                           source_urls
# 2   https://timesofindia.indiatimes.com/city/ranch...
# 4   https://www.newarab.com/news/least-15-killed-i...
# 8   https://www.newsletter.co.uk/news/crime/psni-o...
# 18  https://www.thejc.com/news/uk/anti-fascist-gro...
# 26  https://thehill.com/homenews/ap/ap-top-headlin...

# %%
filtered_geo = cds[cds['geo_type'] == 3]
filtered_geo.head()
# Out:
#     Articles            Description  Magnitud object_type  geo_type  \
# 11         1     CRISISLEX_T03_DEAD      2014        None         3
# 13         1   CRISISLEX_C07_SAFETY         2        None         3
# 25         3                   KILL         6        None         3
# 34         1  CRISISLEX_T02_INJURED        30        None         3
# 63         1                   KILL         2         men         3
#
#                                         geo_fullname Country geo_adm1_code  \
# 11              Mesa County, Colorado, United States      US          USCO
# 13           Montgomery County, Texas, United States      US          USTX
# 25                     Miami, Florida, United States      US          USFL
# 34  White House, District Of Columbia, United States      US          USDC
# 63         Philadelphia, Pennsylvania, United States      US          USPA
#
#     geo_lat  geo_long geo_feature_id       Cameo  \
# 11  39.0333 -108.4670         198154  1191531382
# 13  30.3169  -95.4669        1383955  1191565487
# 25  25.7743  -80.1937         295004  1191655682
# 34  38.8951  -77.0364         531871  1191642501
# 63  39.9523  -75.1638        1209052  1191513816
#
#                              sources  \
# 11                         yahoo.com
# 13                            al.com
# 25  iheart.com;iheart.com;iheart.com
# 34                  democracynow.org
# 63                       vulture.com
#
#                                           source_urls
# 11  https://www.yahoo.com/news/tina-peters-former-...
# 13  https://www.al.com/news/2024/08/alabama-native...
# 25  https://wjno.iheart.com/featured/florida-news/...
# 34  https://www.democracynow.org/2024/8/8/headline...
# 63  https://www.vulture.com/article/pnb-rock-murde...

# %%
filtered_geo = cds[cds['geo_type'] == 2]
filtered_geo.head()
# Out:
#      Articles         Description  Magnitud         object_type  geo_type  \
# 1           1              ARREST       569  attorney Rohrbaugh         2
# 14          1              ARREST        26                None         2
# 44         82  CRISISLEX_T03_DEAD         6                None         2
# 65         96  CRISISLEX_T03_DEAD        12                None         2
# 104         1    SOC_GENERALCRIME         4                None         2
#
#                       geo_fullname Country geo_adm1_code  geo_lat  geo_long  \
# 1              Ohio, United States      US          USOH  40.3736  -82.7755
# 14       California, United States      US          USCA  36.1700 -119.7460
# 44   South Carolina, United States      US          USSC  33.8191  -80.9066
# 65             Utah, United States      US          USUT  40.1135 -111.8540
# 104  South Carolina, United States      US          USSC  33.8191  -80.9066
#
#     geo_feature_id       Cameo  \
# 1               OH  1191578820
# 14              CA  1191649993
# 44              SC  1191513899
# 65              UT  1191584583
# 104             SC  1191652274
#
#                                                sources  \
# 1                                            vindy.com
# 14                                      record-bee.com
# 44   12newsnow.com;knzr.com;wtvr.com;mynorthwest.co...
# 65   kiro7.com;kiro7.com;local10.com;local10.com;wf...
# 104                                 postandcourier.com
#
#                                            source_urls
# 1    https://www.vindy.com/news/local-news/2024/08/...
# 14   https://www.record-bee.com/2024/08/08/news-bri...
# 44   https://www.12newsnow.com/article/news/nation-...
# 65   https://www.kiro7.com/news/national/utah-man-w...
# 104  https://www.postandcourier.com/news/bupeme-pre...

# %%
filtered_geo = cds[cds['geo_type'] == 1]
filtered_geo.head()
# Out:
#    Articles            Description  Magnitud object_type  geo_type  \
# 0         1       SOC_GENERALCRIME        10        None         1
# 3         2  CRISISLEX_T02_INJURED       200        None         1
# 5         1                 TERROR      2000        None         1
# 6        91   CRISISLEX_C07_SAFETY       400        None         1
# 7        91   CRISISLEX_C07_SAFETY       400        None         1
#
#      geo_fullname Country geo_adm1_code  geo_lat  geo_long geo_feature_id  \
# 0          France      FR            FR     46.0       2.0             FR
# 3           China      CH            CH     35.0     105.0             CH
# 5        Honduras      HO            HO     15.0     -86.5             HO
# 6  United Kingdom      UK            UK     54.0      -4.0             UK
# 7  United Kingdom      UK            UK     54.0      -4.0             UK
#
#         Cameo                                            sources  \
# 0  1191594214                              thedrinksbusiness.com
# 3  1191520043                          yahoo.com;newrepublic.com
# 5  1191706419                              canadiandimension.com
# 6  1191553163  bostonglobe.com;thestar.com.my;ctvnews.ca;aol....
# 7  1191697652  bostonglobe.com;thestar.com.my;ctvnews.ca;aol....
#
#                                          source_urls
# 0  https://www.thedrinksbusiness.com/2024/08/trus...
# 3  https://www.yahoo.com/news/american-left-probl...
# 5  https://canadiandimension.com/articles/view/in...
# 6  https://www.bostonglobe.com/2024/08/07/world/f...
# 7  https://www.bostonglobe.com/2024/08/07/world/f...

# %%
cds.columns
# Out:
# Index(['Articles', 'Description', 'Magnitud', 'object_type', 'geo_type',
#        'geo_fullname', 'Country', 'geo_adm1_code', 'geo_lat', 'geo_long',
#        'geo_feature_id', 'Cameo', 'sources', 'source_urls'],
#       dtype='object')

# %%
cds.drop(columns=['object_type', 'geo_type', 'geo_fullname', 'geo_adm1_code', 'geo_lat', 'geo_long', 'geo_feature_id', 'sources'], inplace=True)

cds.head(3)
# Out:
#    Articles       Description  Magnitud Country       Cameo  \
# 0         1  SOC_GENERALCRIME        10      FR  1191594214
# 1         1            ARREST       569      US  1191578820
# 2         1            AFFECT        14      IN  1191534178
#
#                                          source_urls
# 0  https://www.thedrinksbusiness.com/2024/08/trus...
# 1  https://www.vindy.com/news/local-news/2024/08/...
# 2  https://timesofindia.indiatimes.com/city/ranch...

# %% [markdown]
# Note from the GDELT documentation: CAMEOEVENTIDS. (character) This field contains a comma-separated list of GlobalEventIDs
# from the master GDELT event stream of events that were found in the same article(s) as this
# count was found. This can be used, for example, to associate any protest events from the
# primary GDELT event database with any “PROTEST” counts found in the same articles to compile
# a basic measure of how many protesters were involved with the protest. This is useful in that
# the GDELT event record for the protest encodes many other variables, such as the specific actors
# involved and their attributes, while the Count record only records that a certain number of
# protesters were mentioned in an article. The same GlobalEventID may appear in multiple
# entries if multiple counts were found in the same article mentioning that event or if that event
# was mentioned in multiple news articles with different counts (reflecting conflicting or evolving
# information on the details of the event)

# %%
# Export file

#cds.to_csv('c:/Users/dslab/Downloads/counts_dataset_882024.csv')

# %%
# chk = pd.read_csv('c:/Users/dslab/Downloads/counts_dataset_882024.csv')

# chk.shape

# %%
cds['Country'].value_counts()
# Out:
# Country
# IS    62872
# US    40591
# UK    34719
# RS    13320
# BG     9205
#       ...
# BT        3
# CV        2
# GK        1
# GA        1
# SC        1
# Name: count, Length: 160, dtype: int64

# %%
cds_list_countries = eds['action_geo_country_code'].unique()

cds_list_countries
# Out:
# array(['FR', 'US', 'FJ', 'IS', None, 'CA', 'WE', 'QA', 'IN', 'GR', 'SN',
#        'RS', 'AS', 'AU', 'UK', 'BG', 'BR', 'NI', 'IT', 'EI', 'UP', 'CH',
#        'JO', 'GM', 'EG', 'IR', 'GH', 'PC', 'TX', 'GG', 'KS', 'NZ', 'KE',
#        'MX', 'KN', 'RO', 'TU', 'NP', 'IZ', 'AR', 'SP', 'NL', 'SZ', 'PK',
#        'BX', 'BE', 'AY', 'CI', 'VM', 'CO', 'CN', 'SO', 'DR', 'CY', 'HA',
#        'LE', 'ZI', 'SF', 'TT', 'AF', 'FM', 'PO', 'HO', 'SY', 'GA', 'GZ',
#        'JA', 'LY', 'UV', 'ZA', 'MK', 'TW', 'PL', 'JE', 'GT', 'VE', 'TS',
#        'KV', 'RB', 'NU', 'RI', 'AL', 'BO', 'UG', 'CD', 'YM', 'JM', 'LH',
#        'BF', 'NO', 'TH', 'AO', 'FI', 'AE', 'SA', 'CF', 'AJ', 'HU', 'BD',
#        'PM', 'HK', 'RE', 'MY', 'NG', 'SW', 'VT', 'BL', 'GY', 'AC', 'GB',
#        'RP', 'MO', 'PP', 'BH', 'EZ', 'CG', 'CU', 'SU', 'CM', 'FO', 'LG',
#        'MT', 'MU', 'MI', 'LA', 'GV', 'MG', 'BT', 'RW', 'ID', 'PS', 'BK',
#        'DJ', 'TZ', 'TN', 'PE', 'BN', 'GQ', 'OS', 'KZ', 'LT', 'NR', 'WS',
#        'CJ', 'CE', 'AG', 'KU', 'ML', 'ES', 'TD', 'TO', 'BU', 'BY', 'SC',
#        'LI', 'DA', 'RM', 'NC', 'CB', 'SG', 'WA', 'MD', 'BM', 'AA', 'SI',
#        'PA', 'CS', 'EN', 'AM', 'SE', 'MV', 'RQ', 'BC', 'KG', 'MA', 'UZ',
#        'TI', 'OD', 'MZ', 'NH', 'BP', 'MC', 'GJ', 'ET', 'LO', 'BB', 'MP',
#        'SL', 'GK', 'BA', 'TV', 'OC', 'VQ', 'HR', 'IV', 'CV', 'EK', 'MN',
#        'GL', 'UY', 'EC', 'LU', 'FP', 'CT', 'WZ', 'WI', 'LQ', 'NS', 'PG',
#        'IC', 'DO', 'MJ', 'MR', 'MH', 'GI', 'KR', 'VC', 'SV', 'ST', 'FK',
#        'LS', 'PU', 'ER', 'AV', 'MB', 'CW'], dtype=object)

# %%
cds_list_length = len(cds_list_countries)

print("Total number of unique country codes:", cds_list_length)
# Out:
# Total number of unique country codes: 226

# %%
cds['Description'].value_counts()
# Out:
# Description
# KILL                                         61803
# CRISISLEX_T03_DEAD                           40065
# ARREST                                       26224
# CRISISLEX_CRISISLEXREC                       20445
# CRISISLEX_T02_INJURED                        15114
# CRISISLEX_C07_SAFETY                         15020
# AFFECT                                       13740
# WOUND                                        12733
# PROTEST                                      10870
# SOC_GENERALCRIME                             10130
# CRISISLEX_C03_WELLBEING_HEALTH                6261
# KIDNAP                                        4642
# DISPLACED                                     3834
# REFUGEES                                      2799
# CRISISLEX_T01_CAUTION_ADVICE                  2621
# SEIZE                                         2536
# EVACUATION                                    2438
# CRISISLEX_T09_DISPLACEDRELOCATEDEVACUATED     2424
# SOC_POINTSOFINTEREST_JAIL                     1402
# EPU_CATS_MIGRATION_FEAR_MIGRATION             1363
# VIOLENT_UNREST                                1117
# MOVEMENT_GENERAL                              1004
# TAX_FNCACT_ACTIVISTS                           868
# TAX_FNCACT_DEMONSTRATORS                       789
# POVERTY                                        544
# CRISISLEX_C05_NEED_OF_SHELTERS                 544
# TERROR                                         464
# ARMEDCONFLICT                                  448
# CRISISLEX_C04_LOGISTICS_TRANSPORT              287
# STRIKE                                         283
# ASSASSINATION                                  243
# TAX_FNCACT_ACTIVIST                            155
# NATURAL_DISASTER_DROWNED                        63
# RELEASE_HOSTAGE                                 46
# SICKENED                                        43
# HUMAN_RIGHTS_ABUSES_FORCED_MIGRATION            20
# WB_738_SOCIAL_COHESION                          20
# WB_740_FORCED_DISPLACEMENT                      20
# WB_134_SOCIAL_DEVELOPMENT                       20
# SOC_FORCEDRELOCATION                            20
# TAX_FNCACT_STRIKERS                              8
# CRISISLEX_T08_MISSINGFOUNDTRAPPEDPEOPLE          5
# Name: count, dtype: int64

# %%
cds_grp = cds.groupby(["Country", "Description"])['Magnitud'].sum()

cds_grp = cds_grp.reset_index()

cds_grp.tail(12)
# Out:
#      Country                Description  Magnitud
# 1471      ZI       CRISISLEX_C07_SAFETY      5377
# 1472      ZI     CRISISLEX_CRISISLEXREC       952
# 1473      ZI      CRISISLEX_T02_INJURED        94
# 1474      ZI         CRISISLEX_T03_DEAD        84
# 1475      ZI                       KILL      4990
# 1476      ZI           MOVEMENT_GENERAL     10005
# 1477      ZI                    PROTEST     11053
# 1478      ZI           SOC_GENERALCRIME      5086
# 1479      ZI  SOC_POINTSOFINTEREST_JAIL      1286
# 1480      ZI        TAX_FNCACT_ACTIVIST      1575
# 1481      ZI       TAX_FNCACT_ACTIVISTS      8430
# 1482      ZI                      WOUND        94

# %% [markdown]
# ### Checking if Cameo and the Global Event ID can be related among the datasets

# %%
# Data set comparison

cds['Cameo'].isin(eds['global_event_id']).value_counts()
# Out:
# Cameo
# False    263475
# Name: count, dtype: int64

# %%
# Data set comparison

eds['global_event_id'].isin(cds['Cameo']).value_counts()
# Out:
# global_event_id
# False    135253
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Complexity to combine datasets.
# - Interesting data and different angles where to address from.
#
#     <h3> While we decide to pursue or pivot we need to keep processing the data. </h3>
#
# </div>

# %%
cds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263475 entries, 0 to 263474
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Articles     263475 non-null  int32
#  1   Description  263475 non-null  object
#  2   Magnitud     263475 non-null  int64
#  3   Country      259432 non-null  object
#  4   Cameo        263475 non-null  object
#  5   source_urls  263475 non-null  object
# dtypes: int32(1), int64(1), object(4)
# memory usage: 11.1+ MB

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Counts dataset has been assessed and cleaned so now moving into the events file.
#
#     <h3> Not yet joinable but gettign close to connect them. </h3>
#
# </div>

# %% [markdown]
# ### Events Data Profiling
#
# <br/>
#
# > 1. Dimension shape
#
# > 2. Check head and tail
#
# > 3. Review data types, column names, and identify missing data
#
# > 4. Review statistical data for numerical variables
#
# > 5. Determine overall data quality

# %%
eds.shape
# Out:
# (135253, 61)

# %%
eds.head(3)
# Out:
#    global_event_id     sqldate  month_year  year  fraction_date actor_1_code  \
# 0       1191508312  2023-08-09      202308  2023         2023.6         None
# 1       1191508313  2023-08-09      202308  2023         2023.6          BRA
# 2       1191508314  2023-08-09      202308  2023         2023.6          FJI
#
#   actor_1_name actor_1_country_Code actor_1_known_group_code  \
# 0         None                 None                     None
# 1       BRAZIL                  BRA                     None
# 2       FIJIAN                  FJI                     None
#
#   actor_1_ethnic_code  ... action_geo_country_code action_geo_adm1_code  \
# 0                None  ...                      FR                   FR
# 1                None  ...                      US                   US
# 2                None  ...                      FJ                   FJ
#
#   action_geo_lat action_geo_long action_geo_feature_id  \
# 0      46.000000          2.0000                    FR
# 1      39.828175        -98.5795                    US
# 2     -18.000000        178.0000                    FJ
#
#                                           source_url  \
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...
#
#   actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 0                       None                        None
# 1                       None                        None
# 2                       None                          FJ
#
#   actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 0                       None                          FR
# 1                       None                        None
# 2                       None                          FJ
#
# [3 rows x 61 columns]

# %%
eds.tail(3)
# Out:
#         global_event_id     sqldate  month_year  year  fraction_date  \
# 135250       1191708376  2024-08-08      202408  2024      2024.5973
# 135251       1191708377  2024-08-08      202408  2024      2024.5973
# 135252       1191708378  2024-08-08      202408  2024      2024.5973
#
#        actor_1_code actor_1_name actor_1_country_Code  \
# 135250          SCO     SCOTTISH                 None
# 135251          SCO     SCOTTISH                 None
# 135252          SCO     SCOTTISH                 None
#
#        actor_1_known_group_code actor_1_ethnic_code  ...  \
# 135250                     None                 SCO  ...
# 135251                     None                 SCO  ...
# 135252                     None                 SCO  ...
#
#        action_geo_country_code action_geo_adm1_code action_geo_lat  \
# 135250                      US                 USTX        31.1060
# 135251                      UK                 UKW2        55.8333
# 135252                      US                 USTX        31.1060
#
#        action_geo_long action_geo_feature_id  \
# 135250        -97.6475                    TX
# 135251         -4.5000              -2606148
# 135252        -97.6475                    TX
#
#                                             source_url  \
# 135250  https://www.bbc.com/news/articles/clywwzzn14wo
# 135251  https://www.bbc.com/news/articles/clywwzzn14wo
# 135252  https://www.bbc.com/news/articles/clywwzzn14wo
#
#        actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 135250                       None                          TX
# 135251                       None                        None
# 135252                       None                          TX
#
#        actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 135250                       None                        None
# 135251                       None                        None
# 135252                       None                        None
#
# [3 rows x 61 columns]

# %%
eds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135253 entries, 0 to 135252
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   global_event_id              135253 non-null  int32
#  1   sqldate                      135253 non-null  object
#  2   month_year                   135253 non-null  int32
#  3   year                         135253 non-null  int32
#  4   fraction_date                135253 non-null  float64
#  5   actor_1_code                 121754 non-null  object
#  6   actor_1_name                 121754 non-null  object
#  7   actor_1_country_Code         75156 non-null   object
#  8   actor_1_known_group_code     1287 non-null    object
#  9   actor_1_ethnic_code          885 non-null     object
#  10  actor_1_religion_code        1836 non-null    object
#  11  actor_1_religion_2_code      356 non-null     object
#  12  actor_1_type_code            58667 non-null   object
#  13  actor_1_type_2_code          3529 non-null    object
#  14  actor_1_type_3_code          100 non-null     object
#  15  actor_2_code                 95740 non-null   object
#  16  actor_name                   95740 non-null   object
#  17  actor_2_country_code         59489 non-null   object
#  18  actor_2_known_group_code     835 non-null     object
#  19  actor_2_ethnic_code          644 non-null     object
#  20  actor_2_religion_1_code      1500 non-null    object
#  21  actor_2_religion_2_code      258 non-null     object
#  22  actor_2_type_1_code          45649 non-null   object
#  23  actor_2_type_2_code          2404 non-null    object
#  24  actor_2_type_3_code          68 non-null      object
#  25  is_root_event                135253 non-null  int32
#  26  event_code                   135253 non-null  int32
#  27  event_base_code              135253 non-null  int32
#  28  event_root_code              135253 non-null  int32
#  29  quad_class                   135253 non-null  int32
#  30  goldstein_scale              135253 non-null  float64
#  31  num_mentions                 135253 non-null  int32
#  32  num_sources                  135253 non-null  int32
#  33  num_articles                 135253 non-null  int32
#  34  avg_tone                     135253 non-null  float64
#  35  actor_1_geo_type             135253 non-null  int32
#  36  actor_1_geo_fullname         118059 non-null  object
#  37  actor_1_geo_country_code     118091 non-null  object
#  38  actor_1_geo_adm1_code        118091 non-null  object
#  39  actor_1_geo_lat              118059 non-null  float64
#  40  actor_1_geo_long             118072 non-null  float64
#  41  actor_1_geo_feature_id       118091 non-null  object
#  42  actor_2_geo_type             135253 non-null  int32
#  43  actor_2_geo_fullname         92975 non-null   object
#  44  actor_2_geo_country_code     92990 non-null   object
#  45  actor_2_geo_adm1_code        92990 non-null   object
#  46  actor_2_geo_lat              92975 non-null   float64
#  47  actor_2_geo_long             92983 non-null   float64
#  48  actor_2_geo_feature_id       92990 non-null   object
#  49  action_geo_type              135253 non-null  int32
#  50  action_geo_fullname          131186 non-null  object
#  51  action_geo_country_code      131211 non-null  object
#  52  action_geo_adm1_code         131211 non-null  object
#  53  action_geo_lat               131186 non-null  float64
#  54  action_geo_long              131199 non-null  float64
#  55  action_geo_feature_id        131211 non-null  object
#  56  source_url                   135253 non-null  object
#  57  actor_1_geo_feature_id_num   23976 non-null   object
#  58  actor_1_geo_feature_id_text  43985 non-null   object
#  59  actor_2_geo_feature_id_num   17691 non-null   object
#  60  actor_2_geo_feature_id_text  34764 non-null   object
# dtypes: float64(9), int32(14), object(38)
# memory usage: 55.7+ MB

# %%
eds.describe()
# Out:
#        global_event_id     month_year           year  fraction_date  \
# count     1.352530e+05  135253.000000  135253.000000  135253.000000
# mean      1.191608e+09  202407.132182    2023.991379    2024.588108
# std       5.974460e+04      15.443759       0.154439       0.154320
# min       1.191508e+09  201408.000000    2014.000000    2014.605500
# 25%       1.191555e+09  202408.000000    2024.000000    2024.597300
# 50%       1.191609e+09  202408.000000    2024.000000    2024.597300
# 75%       1.191661e+09  202408.000000    2024.000000    2024.597300
# max       1.191708e+09  202408.000000    2024.000000    2024.597300
#
#        is_root_event     event_code  event_base_code  event_root_code  \
# count  135253.000000  135253.000000    135253.000000    135253.000000
# mean        0.605133     101.681094        71.401270         6.957177
# std         0.488824     197.778764        56.243152         5.630334
# min         0.000000      10.000000        10.000000         1.000000
# 25%         0.000000      36.000000        36.000000         3.000000
# 50%         1.000000      46.000000        46.000000         4.000000
# 75%         1.000000     112.000000       111.000000        11.000000
# max         1.000000    1832.000000       203.000000        20.000000
#
#           quad_class  goldstein_scale  ...       avg_tone  actor_1_geo_type  \
# count  135253.000000    135253.000000  ...  135253.000000     135253.000000
# mean        1.838577         0.353476  ...      -2.193628          2.518192
# std         1.146697         4.686513  ...       4.286355          1.511944
# min         1.000000       -10.000000  ...     -30.000000          0.000000
# 25%         1.000000        -2.000000  ...      -5.160391          1.000000
# 50%         1.000000         1.000000  ...      -2.217295          3.000000
# 75%         3.000000         3.400000  ...       0.729927          4.000000
# max         4.000000        10.000000  ...      23.076923          5.000000
#
#        actor_1_geo_lat  actor_1_geo_long  actor_2_geo_type  actor_2_geo_lat  \
# count    118059.000000     118072.000000     135253.000000     92975.000000
# mean         31.466319         -5.576096          1.984932        31.558697
# std          20.845873         78.104669          1.701832        20.586585
# min         -85.622100       -176.533000          0.000000       -85.622100
# 25%          25.083300        -81.717000          0.000000        25.183300
# 50%          35.925500          2.183330          2.000000        35.750000
# 75%          44.239400         42.000000          4.000000        44.239400
# max          79.209300        180.000000          5.000000        78.000000
#
#        actor_2_geo_long  action_geo_type  action_geo_lat  action_geo_long
# count      92983.000000    135253.000000   131186.000000    131199.000000
# mean          -1.821727         2.811139       31.350373        -6.198391
# std           77.148142         1.319632       20.882310        78.603947
# min         -175.000000         0.000000      -85.622100      -176.533000
# 25%          -79.843100         2.000000       25.047800       -82.133200
# 50%            7.533330         3.000000       35.810900         2.000000
# 75%           44.513600         4.000000       43.739400        42.572400
# max          179.367000         5.000000       79.209300       180.000000
#
# [8 rows x 23 columns]

# %%
eds['action_geo_type'].value_counts()
# Out:
# action_geo_type
# 4    57691
# 1    28853
# 3    22593
# 2    19162
# 0     4055
# 5     2899
# Name: count, dtype: int64

# %%
eds['actor_1_geo_type'].value_counts()
# Out:
# actor_1_geo_type
# 4    51959
# 1    26666
# 3    19628
# 2    17306
# 0    17175
# 5     2519
# Name: count, dtype: int64

# %%
eds['actor_2_geo_type'].value_counts()
# Out:
# actor_2_geo_type
# 4    42325
# 0    42271
# 1    21931
# 3    13959
# 2    12825
# 5     1942
# Name: count, dtype: int64

# %% [markdown]
# ### EDA at the eds (acronym for Events Data Set) dataset
#
# #### Assess information gain given our objective to:
# <br/>
#
# > 1. Remove columns or rows that are not needed
#
# > 2. Rename columns
#
# > 3. Address missing data
#
# > 4. Ensure proper formatting
#
# > 5. Sort as needed
#
# > 6. Slice or Group as needed
#
# > 7. Add feature engineering

# %%
eds.columns
# Out:
# Index(['global_event_id', 'sqldate', 'month_year', 'year', 'fraction_date',
#        'actor_1_code', 'actor_1_name', 'actor_1_country_Code',
#        'actor_1_known_group_code', 'actor_1_ethnic_code',
#        'actor_1_religion_code', 'actor_1_religion_2_code', 'actor_1_type_code',
#        'actor_1_type_2_code', 'actor_1_type_3_code', 'actor_2_code',
#        'actor_name', 'actor_2_country_code', 'actor_2_known_group_code',
#        'actor_2_ethnic_code', 'actor_2_religion_1_code',
#        'actor_2_religion_2_code', 'actor_2_type_1_code', 'actor_2_type_2_code',
#        'actor_2_type_3_code', 'is_root_event', 'event_code', 'event_base_code',
#        'event_root_code', 'quad_class', 'goldstein_scale', 'num_mentions',
#        'num_sources', 'num_articles', 'avg_tone', 'actor_1_geo_type',
#        'actor_1_geo_fullname', 'actor_1_geo_country_code',
#        'actor_1_geo_adm1_code', 'actor_1_geo_lat', 'actor_1_geo_long',
#        'actor_1_geo_feature_id', 'actor_2_geo_type', 'actor_2_geo_fullname',
#        'actor_2_geo_country_code', 'actor_2_geo_adm1_code', 'actor_2_geo_lat',
#        'actor_2_geo_long', 'actor_2_geo_feature_id', 'action_geo_type',
#        'action_geo_fullname', 'action_geo_country_code',
#        'action_geo_adm1_code', 'action_geo_lat', 'action_geo_long',
#        'action_geo_feature_id', 'source_url', 'actor_1_geo_feature_id_num',
#        'actor_1_geo_feature_id_text', 'actor_2_geo_feature_id_num',
#        'actor_2_geo_feature_id_text'],
#       dtype='object')

# %%
checksomecols = eds[['action_geo_type',
       'action_geo_fullname', 'action_geo_country_code',
       'action_geo_adm1_code', 'action_geo_lat', 'action_geo_long',
       'action_geo_feature_id', 'source_url']]

checksomecols.head(3)
# Out:
#    action_geo_type action_geo_fullname action_geo_country_code  \
# 0                1              France                      FR
# 1                1       United States                      US
# 2                1                Fiji                      FJ
#
#   action_geo_adm1_code  action_geo_lat  action_geo_long action_geo_feature_id  \
# 0                   FR       46.000000           2.0000                    FR
# 1                   US       39.828175         -98.5795                    US
# 2                   FJ      -18.000000         178.0000                    FJ
#
#                                           source_url
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...

# %%
eds['action_geo_country_code'].dtypes
# Out:
# dtype('O')

# %%
eds['action_geo_country_code'].value_counts()
# Out:
# action_geo_country_code
# US    43962
# UK     9563
# IS     6632
# IN     5937
# RS     3545
#       ...
# MB        2
# LQ        1
# FO        1
# FK        1
# LS        1
# Name: count, Length: 225, dtype: int64

# %%
eds_list_countries = eds['action_geo_country_code'].unique()

eds_list_countries
# Out:
# array(['FR', 'US', 'FJ', 'IS', None, 'CA', 'WE', 'QA', 'IN', 'GR', 'SN',
#        'RS', 'AS', 'AU', 'UK', 'BG', 'BR', 'NI', 'IT', 'EI', 'UP', 'CH',
#        'JO', 'GM', 'EG', 'IR', 'GH', 'PC', 'TX', 'GG', 'KS', 'NZ', 'KE',
#        'MX', 'KN', 'RO', 'TU', 'NP', 'IZ', 'AR', 'SP', 'NL', 'SZ', 'PK',
#        'BX', 'BE', 'AY', 'CI', 'VM', 'CO', 'CN', 'SO', 'DR', 'CY', 'HA',
#        'LE', 'ZI', 'SF', 'TT', 'AF', 'FM', 'PO', 'HO', 'SY', 'GA', 'GZ',
#        'JA', 'LY', 'UV', 'ZA', 'MK', 'TW', 'PL', 'JE', 'GT', 'VE', 'TS',
#        'KV', 'RB', 'NU', 'RI', 'AL', 'BO', 'UG', 'CD', 'YM', 'JM', 'LH',
#        'BF', 'NO', 'TH', 'AO', 'FI', 'AE', 'SA', 'CF', 'AJ', 'HU', 'BD',
#        'PM', 'HK', 'RE', 'MY', 'NG', 'SW', 'VT', 'BL', 'GY', 'AC', 'GB',
#        'RP', 'MO', 'PP', 'BH', 'EZ', 'CG', 'CU', 'SU', 'CM', 'FO', 'LG',
#        'MT', 'MU', 'MI', 'LA', 'GV', 'MG', 'BT', 'RW', 'ID', 'PS', 'BK',
#        'DJ', 'TZ', 'TN', 'PE', 'BN', 'GQ', 'OS', 'KZ', 'LT', 'NR', 'WS',
#        'CJ', 'CE', 'AG', 'KU', 'ML', 'ES', 'TD', 'TO', 'BU', 'BY', 'SC',
#        'LI', 'DA', 'RM', 'NC', 'CB', 'SG', 'WA', 'MD', 'BM', 'AA', 'SI',
#        'PA', 'CS', 'EN', 'AM', 'SE', 'MV', 'RQ', 'BC', 'KG', 'MA', 'UZ',
#        'TI', 'OD', 'MZ', 'NH', 'BP', 'MC', 'GJ', 'ET', 'LO', 'BB', 'MP',
#        'SL', 'GK', 'BA', 'TV', 'OC', 'VQ', 'HR', 'IV', 'CV', 'EK', 'MN',
#        'GL', 'UY', 'EC', 'LU', 'FP', 'CT', 'WZ', 'WI', 'LQ', 'NS', 'PG',
#        'IC', 'DO', 'MJ', 'MR', 'MH', 'GI', 'KR', 'VC', 'SV', 'ST', 'FK',
#        'LS', 'PU', 'ER', 'AV', 'MB', 'CW'], dtype=object)

# %%
eds_list_length = len(eds_list_countries)

print("Unique country codes:", eds_list_length)
# Out:
# Unique country codes: 226

# %%
print("Do both datasets have the same countries? :", cds_list_length == eds_list_length)
# Out:
# Do both datasets have the same countries? : True

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - There is a different distribution within each dataset for each country.
#
#     <h3> Yet both datasets have all the same countries. </h3>
#
# </div>

# %%
eds.rename(columns={'action_geo_country_code': 'Country'}, inplace=True)
                    
eds.head(1)
# Out:
#    global_event_id     sqldate  month_year  year  fraction_date actor_1_code  \
# 0       1191508312  2023-08-09      202308  2023         2023.6         None
#
#   actor_1_name actor_1_country_Code actor_1_known_group_code  \
# 0         None                 None                     None
#
#   actor_1_ethnic_code  ... Country action_geo_adm1_code action_geo_lat  \
# 0                None  ...      FR                   FR           46.0
#
#   action_geo_long action_geo_feature_id  \
# 0             2.0                    FR
#
#                                           source_url  \
# 0  https://coast1009.com/us-news/wrongful-death-l...
#
#   actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 0                       None                        None
#
#   actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 0                       None                          FR
#
# [1 rows x 61 columns]

# %%
eds.columns
# Out:
# Index(['global_event_id', 'sqldate', 'month_year', 'year', 'fraction_date',
#        'actor_1_code', 'actor_1_name', 'actor_1_country_Code',
#        'actor_1_known_group_code', 'actor_1_ethnic_code',
#        'actor_1_religion_code', 'actor_1_religion_2_code', 'actor_1_type_code',
#        'actor_1_type_2_code', 'actor_1_type_3_code', 'actor_2_code',
#        'actor_name', 'actor_2_country_code', 'actor_2_known_group_code',
#        'actor_2_ethnic_code', 'actor_2_religion_1_code',
#        'actor_2_religion_2_code', 'actor_2_type_1_code', 'actor_2_type_2_code',
#        'actor_2_type_3_code', 'is_root_event', 'event_code', 'event_base_code',
#        'event_root_code', 'quad_class', 'goldstein_scale', 'num_mentions',
#        'num_sources', 'num_articles', 'avg_tone', 'actor_1_geo_type',
#        'actor_1_geo_fullname', 'actor_1_geo_country_code',
#        'actor_1_geo_adm1_code', 'actor_1_geo_lat', 'actor_1_geo_long',
#        'actor_1_geo_feature_id', 'actor_2_geo_type', 'actor_2_geo_fullname',
#        'actor_2_geo_country_code', 'actor_2_geo_adm1_code', 'actor_2_geo_lat',
#        'actor_2_geo_long', 'actor_2_geo_feature_id', 'action_geo_type',
#        'action_geo_fullname', 'Country', 'action_geo_adm1_code',
#        'action_geo_lat', 'action_geo_long', 'action_geo_feature_id',
#        'source_url', 'actor_1_geo_feature_id_num',
#        'actor_1_geo_feature_id_text', 'actor_2_geo_feature_id_num',
#        'actor_2_geo_feature_id_text'],
#       dtype='object')

# %%
eds.drop(columns=['month_year', 'year', 'fraction_date',
       'actor_1_code', 'actor_1_name', 'actor_1_country_Code',
       'actor_1_known_group_code', 'actor_1_ethnic_code',
       'actor_1_religion_code', 'actor_1_religion_2_code', 'actor_1_type_code',
       'actor_1_type_2_code', 'actor_1_type_3_code', 'actor_2_code',
       'actor_name', 'actor_2_country_code', 'actor_2_known_group_code',
       'actor_2_ethnic_code', 'actor_2_religion_1_code',
       'actor_2_religion_2_code', 'actor_2_type_1_code', 'actor_2_type_2_code',
       'actor_2_type_3_code', 'num_sources', 'event_base_code', 'event_root_code'], inplace=True)

eds.head(3)
# Out:
#    global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 0       1191508312  2023-08-09              1         115           3
# 1       1191508313  2023-08-09              1          10           1
# 2       1191508314  2023-08-09              0          71           2
#
#    goldstein_scale  num_mentions  num_articles  avg_tone  actor_1_geo_type  \
# 0             -2.0           220           220 -4.232628                 0
# 1              0.0             2             2 -7.007844                 4
# 2              7.4             2             2 -6.618705                 1
#
#    ... Country action_geo_adm1_code action_geo_lat  action_geo_long  \
# 0  ...      FR                   FR      46.000000           2.0000
# 1  ...      US                   US      39.828175         -98.5795
# 2  ...      FJ                   FJ     -18.000000         178.0000
#
#    action_geo_feature_id                                         source_url  \
# 0                     FR  https://coast1009.com/us-news/wrongful-death-l...
# 1                     US  https://www.terradaily.com/afp/240807204524.p6...
# 2                     FJ  https://www.rnz.co.nz/international/pacific-ne...
#
#    actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 0                        None                        None
# 1                        None                        None
# 2                        None                          FJ
#
#   actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 0                       None                          FR
# 1                       None                        None
# 2                       None                          FJ
#
# [3 rows x 35 columns]

# %%
eds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135253 entries, 0 to 135252
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   global_event_id              135253 non-null  int32
#  1   sqldate                      135253 non-null  object
#  2   is_root_event                135253 non-null  int32
#  3   event_code                   135253 non-null  int32
#  4   quad_class                   135253 non-null  int32
#  5   goldstein_scale              135253 non-null  float64
#  6   num_mentions                 135253 non-null  int32
#  7   num_articles                 135253 non-null  int32
#  8   avg_tone                     135253 non-null  float64
#  9   actor_1_geo_type             135253 non-null  int32
#  10  actor_1_geo_fullname         118059 non-null  object
#  11  actor_1_geo_country_code     118091 non-null  object
#  12  actor_1_geo_adm1_code        118091 non-null  object
#  13  actor_1_geo_lat              118059 non-null  float64
#  14  actor_1_geo_long             118072 non-null  float64
#  15  actor_1_geo_feature_id       118091 non-null  object
#  16  actor_2_geo_type             135253 non-null  int32
#  17  actor_2_geo_fullname         92975 non-null   object
#  18  actor_2_geo_country_code     92990 non-null   object
#  19  actor_2_geo_adm1_code        92990 non-null   object
#  20  actor_2_geo_lat              92975 non-null   float64
#  21  actor_2_geo_long             92983 non-null   float64
#  22  actor_2_geo_feature_id       92990 non-null   object
#  23  action_geo_type              135253 non-null  int32
#  24  action_geo_fullname          131186 non-null  object
#  25  Country                      131211 non-null  object
#  26  action_geo_adm1_code         131211 non-null  object
#  27  action_geo_lat               131186 non-null  float64
#  28  action_geo_long              131199 non-null  float64
#  29  action_geo_feature_id        131211 non-null  object
#  30  source_url                   135253 non-null  object
#  31  actor_1_geo_feature_id_num   23976 non-null   object
#  32  actor_1_geo_feature_id_text  43985 non-null   object
#  33  actor_2_geo_feature_id_num   17691 non-null   object
#  34  actor_2_geo_feature_id_text  34764 non-null   object
# dtypes: float64(8), int32(9), object(18)
# memory usage: 31.5+ MB

# %%
checksomecols2 = eds[['action_geo_adm1_code',
       'action_geo_lat', 'action_geo_long', 'action_geo_feature_id',
       'source_url', 'actor_1_geo_feature_id_num',
       'actor_1_geo_feature_id_text', 'actor_2_geo_feature_id_num',
       'actor_2_geo_feature_id_text']]

checksomecols2.head(3)
# Out:
#   action_geo_adm1_code  action_geo_lat  action_geo_long action_geo_feature_id  \
# 0                   FR       46.000000           2.0000                    FR
# 1                   US       39.828175         -98.5795                    US
# 2                   FJ      -18.000000         178.0000                    FJ
#
#                                           source_url  \
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...
#
#   actor_1_geo_feature_id_num actor_1_geo_feature_id_text  \
# 0                       None                        None
# 1                       None                        None
# 2                       None                          FJ
#
#   actor_2_geo_feature_id_num actor_2_geo_feature_id_text
# 0                       None                          FR
# 1                       None                        None
# 2                       None                          FJ

# %%
eds.drop(columns=['action_geo_adm1_code','action_geo_lat', 'action_geo_long', 'action_geo_feature_id','actor_1_geo_feature_id_num','actor_1_geo_feature_id_text', 'actor_2_geo_feature_id_num','actor_2_geo_feature_id_text'], inplace=True)

eds.head(3)
# Out:
#    global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 0       1191508312  2023-08-09              1         115           3
# 1       1191508313  2023-08-09              1          10           1
# 2       1191508314  2023-08-09              0          71           2
#
#    goldstein_scale  num_mentions  num_articles  avg_tone  actor_1_geo_type  \
# 0             -2.0           220           220 -4.232628                 0
# 1              0.0             2             2 -7.007844                 4
# 2              7.4             2             2 -6.618705                 1
#
#    ... actor_2_geo_fullname actor_2_geo_country_code actor_2_geo_adm1_code  \
# 0  ...               France                       FR                    FR
# 1  ...                 None                     None                  None
# 2  ...                 Fiji                       FJ                    FJ
#
#    actor_2_geo_lat  actor_2_geo_long actor_2_geo_feature_id  action_geo_type  \
# 0             46.0               2.0                     FR                1
# 1              NaN               NaN                   None                1
# 2            -18.0             178.0                     FJ                1
#
#   action_geo_fullname Country  \
# 0              France      FR
# 1       United States      US
# 2                Fiji      FJ
#
#                                           source_url
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...
#
# [3 rows x 27 columns]

# %%
eds.columns
# Out:
# Index(['global_event_id', 'sqldate', 'is_root_event', 'event_code',
#        'quad_class', 'goldstein_scale', 'num_mentions', 'num_articles',
#        'avg_tone', 'actor_1_geo_type', 'actor_1_geo_fullname',
#        'actor_1_geo_country_code', 'actor_1_geo_adm1_code', 'actor_1_geo_lat',
#        'actor_1_geo_long', 'actor_1_geo_feature_id', 'actor_2_geo_type',
#        'actor_2_geo_fullname', 'actor_2_geo_country_code',
#        'actor_2_geo_adm1_code', 'actor_2_geo_lat', 'actor_2_geo_long',
#        'actor_2_geo_feature_id', 'action_geo_type', 'action_geo_fullname',
#        'Country', 'source_url'],
#       dtype='object')

# %%
eds.drop(columns=['actor_1_geo_type', 'actor_1_geo_fullname', 'actor_1_geo_country_code',
       'actor_1_geo_adm1_code', 'actor_1_geo_lat', 'actor_1_geo_long',
       'actor_1_geo_feature_id', 'actor_2_geo_type', 'actor_2_geo_fullname',
       'actor_2_geo_country_code', 'actor_2_geo_adm1_code', 'actor_2_geo_lat',
       'actor_2_geo_long', 'actor_2_geo_feature_id', 'action_geo_type',
       'action_geo_fullname'], inplace=True)

eds.head(3)
# Out:
#    global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 0       1191508312  2023-08-09              1         115           3
# 1       1191508313  2023-08-09              1          10           1
# 2       1191508314  2023-08-09              0          71           2
#
#    goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 0             -2.0           220           220 -4.232628      FR
# 1              0.0             2             2 -7.007844      US
# 2              7.4             2             2 -6.618705      FJ
#
#                                           source_url
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...

# %%
eds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135253 entries, 0 to 135252
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   global_event_id  135253 non-null  int32
#  1   sqldate          135253 non-null  object
#  2   is_root_event    135253 non-null  int32
#  3   event_code       135253 non-null  int32
#  4   quad_class       135253 non-null  int32
#  5   goldstein_scale  135253 non-null  float64
#  6   num_mentions     135253 non-null  int32
#  7   num_articles     135253 non-null  int32
#  8   avg_tone         135253 non-null  float64
#  9   Country          131211 non-null  object
#  10  source_url       135253 non-null  object
# dtypes: float64(2), int32(6), object(3)
# memory usage: 8.3+ MB

# %%
eds.columns
# Out:
# Index(['global_event_id', 'sqldate', 'is_root_event', 'event_code',
#        'quad_class', 'goldstein_scale', 'num_mentions', 'num_articles',
#        'avg_tone', 'Country', 'source_url'],
#       dtype='object')

# %%
eds.head()
# Out:
#    global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 0       1191508312  2023-08-09              1         115           3
# 1       1191508313  2023-08-09              1          10           1
# 2       1191508314  2023-08-09              0          71           2
# 3       1191508315  2023-08-09              0          71           2
# 4       1191508316  2023-08-09              0         141           3
#
#    goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 0             -2.0           220           220 -4.232628      FR
# 1              0.0             2             2 -7.007844      US
# 2              7.4             2             2 -6.618705      FJ
# 3              7.4             5             5 -6.618705      FJ
# 4             -6.5             1             1 -4.058442      IS
#
#                                           source_url
# 0  https://coast1009.com/us-news/wrongful-death-l...
# 1  https://www.terradaily.com/afp/240807204524.p6...
# 2  https://www.rnz.co.nz/international/pacific-ne...
# 3  https://www.rnz.co.nz/international/pacific-ne...
# 4  https://www.middleeasteye.net/news/canadian-ma...

# %%
eds['Country'].isnull().sum().sum()
# Out:
# 4042

# %%
missing_values_sample = eds[eds['Country'].isna()]

missing_values_sample.head()
# Out:
#     global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 6        1191508318  2023-08-09              0          71           2
# 8        1191508320  2023-08-09              1          42           1
# 15       1191508327  2023-08-09              1          43           1
# 60       1191508372  2024-08-07              1          90           2
# 61       1191508373  2024-08-07              1          43           1
#
#     goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 6               7.4            10            10 -4.941860    None
# 8               1.9             5             5 -1.428571    None
# 15              2.8             5             5 -1.428571    None
# 60             -2.0             5             5  2.813299    None
# 61              2.8             5             5  2.813299    None
#
#                                            source_url
# 6   https://www.yahoo.com/news/thief-posing-las-ve...
# 8   https://www.yahoo.com/news/boeing-starliner-as...
# 15  https://www.yahoo.com/news/boeing-starliner-as...
# 60  https://www.miragenews.com/new-research-facili...
# 61  https://www.miragenews.com/new-research-facili...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - There are no other more complete columns we can grab so that all dataset has a country.
# - This is the last step to ensure there are no missing values to deal with.
#
#     <h3> Since without an identified country the row becomes useless for analytics, need to drop those rows without country. </h3>
#
# </div>

# %%
eds = eds.dropna(subset=['Country'])

eds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131211 entries, 0 to 135252
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   global_event_id  131211 non-null  int32
#  1   sqldate          131211 non-null  object
#  2   is_root_event    131211 non-null  int32
#  3   event_code       131211 non-null  int32
#  4   quad_class       131211 non-null  int32
#  5   goldstein_scale  131211 non-null  float64
#  6   num_mentions     131211 non-null  int32
#  7   num_articles     131211 non-null  int32
#  8   avg_tone         131211 non-null  float64
#  9   Country          131211 non-null  object
#  10  source_url       131211 non-null  object
# dtypes: float64(2), int32(6), object(3)
# memory usage: 9.0+ MB

# %%
eds
# Out:
#         global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 0            1191508312  2023-08-09              1         115           3
# 1            1191508313  2023-08-09              1          10           1
# 2            1191508314  2023-08-09              0          71           2
# 3            1191508315  2023-08-09              0          71           2
# 4            1191508316  2023-08-09              0         141           3
# ...                 ...         ...            ...         ...         ...
# 135248       1191708374  2024-08-08              0          51           1
# 135249       1191708375  2024-08-08              0          12           1
# 135250       1191708376  2024-08-08              0          20           1
# 135251       1191708377  2024-08-08              1          84           2
# 135252       1191708378  2024-08-08              1          84           2
#
#         goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 0                  -2.0           220           220 -4.232628      FR
# 1                   0.0             2             2 -7.007844      US
# 2                   7.4             2             2 -6.618705      FJ
# 3                   7.4             5             5 -6.618705      FJ
# 4                  -6.5             1             1 -4.058442      IS
# ...                 ...           ...           ...       ...     ...
# 135248              3.4             6             6  1.416765      CA
# 135249             -0.4            10            10 -2.985075      US
# 135250              3.0            10            10 -2.985075      US
# 135251              7.0            10            10 -2.985075      UK
# 135252              7.0            10            10 -2.985075      US
#
#                                                source_url
# 0       https://coast1009.com/us-news/wrongful-death-l...
# 1       https://www.terradaily.com/afp/240807204524.p6...
# 2       https://www.rnz.co.nz/international/pacific-ne...
# 3       https://www.rnz.co.nz/international/pacific-ne...
# 4       https://www.middleeasteye.net/news/canadian-ma...
# ...                                                   ...
# 135248  https://vancouversun.com:443/news/bc-health-ex...
# 135249     https://www.bbc.com/news/articles/clywwzzn14wo
# 135250     https://www.bbc.com/news/articles/clywwzzn14wo
# 135251     https://www.bbc.com/news/articles/clywwzzn14wo
# 135252     https://www.bbc.com/news/articles/clywwzzn14wo
#
# [131211 rows x 11 columns]

# %%
eds.columns
# Out:
# Index(['global_event_id', 'sqldate', 'is_root_event', 'event_code',
#        'quad_class', 'goldstein_scale', 'num_mentions', 'num_articles',
#        'avg_tone', 'Country', 'source_url'],
#       dtype='object')

# %%
# Check as these columns are very similar

num_mentions = eds['num_mentions'].sum()

num_articles = eds['num_articles'].sum()

print("Comparing these two columns to see if the have the same total number boolean:", num_mentions == num_articles)
print()
print("Comparing these two columns to see if the have the same total number numeric:", num_mentions - num_articles)
# Out:
# Comparing these two columns to see if the have the same total number boolean: False
#
# Comparing these two columns to see if the have the same total number numeric: 38395

# %%
eds_grp = eds.groupby(["Country", "event_code"])['event_code'].count()

#eds_grp = eds_grp.reset_index()

eds_grp.tail(12)
# Out:
# Country  event_code
# ZI       181           1
#          190           4
#          192           1
#          193           2
#          311           2
#          353           1
#          831           2
#          841           2
#          1121          1
#          1723          1
#          1821          2
#          1822          7
# Name: event_code, dtype: int64

# %%
eds_grp.head(12)
# Out:
# Country  event_code
# AA       10            1
#          72            1
#          80            1
#          90            1
#          111           1
# AC       10            7
#          12            1
#          13            3
#          17            3
#          20            2
#          36            2
#          40            2
# Name: event_code, dtype: int64

# %%
eds2_grp = eds.groupby(["Country", "event_code", "goldstein_scale"])['goldstein_scale'].median()

#eds_grp = eds_grp.reset_index()

eds2_grp.head(6)
# Out:
# Country  event_code  goldstein_scale
# AA       10           0.0               0.0
#          72           8.3               8.3
#          80           5.0               5.0
#          90          -2.0              -2.0
#          111         -2.0              -2.0
# AC       10           0.0               0.0
# Name: goldstein_scale, dtype: float64

# %%
eds3_grp = eds.groupby(["Country", "event_code", "goldstein_scale"])['goldstein_scale'].mean()

#eds_grp = eds_grp.reset_index()

eds3_grp.head(6)
# Out:
# Country  event_code  goldstein_scale
# AA       10           0.0               0.0
#          72           8.3               8.3
#          80           5.0               5.0
#          90          -2.0              -2.0
#          111         -2.0              -2.0
# AC       10           0.0               0.0
# Name: goldstein_scale, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Performed confirmation on expecation on the Goldstein Scale to consider it be used as a scalar to build an index.
# - Here the expectation: GoldsteinScale. (numeric) Each CAMEO event code is assigned a numeric score from -10 to +10,
# capturing the theoretical potential impact that type of event will have on the stability of a
# country. This is known as the Goldstein Scale. This field specifies the Goldstein score for each
# event type. NOTE: this score is based on the type of event, not the specifics of the actual event
# record being recorded – thus two riots, one with 10 people and one with 10,000, will both
# receive the same Goldstein score. This can be aggregated to various levels of time resolution to
# yield an approximation of the stability of a location over time.
#
#     - Source: http://data.gdeltproject.org/documentation/GDELT-Data_Format_Codebook.pdf
#
#     <h3> So goldstein scan can indeed help as a scalar to build an index. </h3>
#
# </div>

# %%
mini_eds = eds[["event_code", "goldstein_scale"]]

scalar = mini_eds.groupby(["event_code", "goldstein_scale"])

#scalar = eds_grp.reset_index()

scalar.head(6)
# Out:
#         event_code  goldstein_scale
# 0              115             -2.0
# 1               10              0.0
# 2               71              7.4
# 3               71              7.4
# 4              141             -6.5
# ...            ...              ...
# 123706        1244             -4.0
# 130076         107             -5.0
# 130497         107             -5.0
# 131655        1662             -7.0
# 131836         872              9.0
#
# [1150 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Good intention yet need to produce without duplicates.
#
#     <h3> Aiming for a shorter list. </h3>
#
# </div>

# %%
mini_eds = eds[["event_code", "goldstein_scale"]]

scalar = mini_eds.groupby(["event_code", "goldstein_scale"])['event_code'].count()

#scalar = scalar.reset_index()

scalar.tail(6)
# Out:
# event_code  goldstein_scale
# 1724        -5.0                32
# 1821        -9.0               199
# 1822        -9.0               146
# 1823        -10.0               47
# 1831        -10.0               20
# 1832        -10.0                5
# Name: event_code, dtype: int64

# %%
scalar = eds.groupby(["event_code", "goldstein_scale"])['event_code'].count()

#scalar = scalar.reset_index()

scalar.tail(6)
# Out:
# event_code  goldstein_scale
# 1724        -5.0                32
# 1821        -9.0               199
# 1822        -9.0               146
# 1823        -10.0               47
# 1831        -10.0               20
# 1832        -10.0                5
# Name: event_code, dtype: int64

# %%
goldstein_scale_distribution = eds.groupby('goldstein_scale').agg({'event_code': 'count'}).reset_index()

goldstein_scale_distribution.head()
# Out:
#    goldstein_scale  event_code
# 0            -10.0        7918
# 1             -9.5        1168
# 2             -9.2         412
# 3             -9.0        1781
# 4             -8.0         159

# %%
improved_scalar = mini_eds.groupby(["event_code", "goldstein_scale"]).count().reset_index()

improved_scalar
# Out:
#      event_code  goldstein_scale
# 0            10              0.0
# 1            11             -0.1
# 2            12             -0.4
# 3            13              0.4
# 4            14              0.0
# ..          ...              ...
# 202        1821             -9.0
# 203        1822             -9.0
# 204        1823            -10.0
# 205        1831            -10.0
# 206        1832            -10.0
#
# [207 rows x 2 columns]

# %%
# Using one of the worst valued Cameo codes that have happened

check_cameo_code_1832 = eds[eds['event_code'] == 1832]

check_cameo_code_1832
# Out:
#        global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 53606       1191588031  2024-08-08              0        1832           4
# 77525       1191624194  2024-08-08              1        1832           4
# 77526       1191624195  2024-08-08              1        1832           4
# 77532       1191624201  2024-08-08              1        1832           4
# 77533       1191624202  2024-08-08              1        1832           4
#
#        goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 53606            -10.0             5             5 -6.666667      IS
# 77525            -10.0             1             1 -5.809129      IS
# 77526            -10.0             1             1 -5.809129      IS
# 77532            -10.0             2             2 -5.809129      IS
# 77533            -10.0             1             1 -5.809129      IS
#
#                                               source_url
# 53606  https://www.jewishpress.com/news/eye-on-palest...
# 77525  https://www.dailysabah.com/politics/diplomacy/...
# 77526  https://www.dailysabah.com/politics/diplomacy/...
# 77532  https://www.dailysabah.com/politics/diplomacy/...
# 77533  https://www.dailysabah.com/politics/diplomacy/...

# %%
check_cameo_code_1832.columns
# Out:
# Index(['global_event_id', 'sqldate', 'is_root_event', 'event_code',
#        'quad_class', 'goldstein_scale', 'num_mentions', 'num_articles',
#        'avg_tone', 'Country', 'source_url'],
#       dtype='object')

# %%
mini_check_cameo_code_1832 = check_cameo_code_1832[['global_event_id', 'sqldate', 'is_root_event', 'event_code', 'num_mentions', 'num_articles', 'avg_tone', 'Country', 'source_url']]

mini_check_cameo_code_1832
# Out:
#        global_event_id     sqldate  is_root_event  event_code  num_mentions  \
# 53606       1191588031  2024-08-08              0        1832             5
# 77525       1191624194  2024-08-08              1        1832             1
# 77526       1191624195  2024-08-08              1        1832             1
# 77532       1191624201  2024-08-08              1        1832             2
# 77533       1191624202  2024-08-08              1        1832             1
#
#        num_articles  avg_tone Country  \
# 53606             5 -6.666667      IS
# 77525             1 -5.809129      IS
# 77526             1 -5.809129      IS
# 77532             2 -5.809129      IS
# 77533             1 -5.809129      IS
#
#                                               source_url
# 53606  https://www.jewishpress.com/news/eye-on-palest...
# 77525  https://www.dailysabah.com/politics/diplomacy/...
# 77526  https://www.dailysabah.com/politics/diplomacy/...
# 77532  https://www.dailysabah.com/politics/diplomacy/...
# 77533  https://www.dailysabah.com/politics/diplomacy/...

# %%
check_cameo_code_1832.count()
# Out:
# global_event_id    5
# sqldate            5
# is_root_event      5
# event_code         5
# quad_class         5
# goldstein_scale    5
# num_mentions       5
# num_articles       5
# avg_tone           5
# Country            5
# source_url         5
# dtype: int64

# %%
eds['is_root_event'].value_counts()
# Out:
# is_root_event
# 1    78470
# 0    52741
# Name: count, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)

# %%
print(check_cameo_code_1832['source_url'])
# Out:
# 53606    https://www.jewishpress.com/news/eye-on-palestine/hamas/idf-eliminates-another-senior-hamas-terrorist-in-gaza-but-not-sinwar/2024/08/08/
# 77525                                            https://www.dailysabah.com/politics/diplomacy/erdogan-qatari-emir-meet-as-regional-tensions-rise
# 77526                                            https://www.dailysabah.com/politics/diplomacy/erdogan-qatari-emir-meet-as-regional-tensions-rise
# 77532                                            https://www.dailysabah.com/politics/diplomacy/erdogan-qatari-emir-meet-as-regional-tensions-rise
# 77533                                            https://www.dailysabah.com/politics/diplomacy/erdogan-qatari-emir-meet-as-regional-tensions-rise
# Name: source_url, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Interesting findings as root source is grouping other events thus we need to filter by is_root_event == 0 (actually would have expected to be == 1 as usually 1 refers to Yes or True).
#     - Source: http://data.gdeltproject.org/documentation/CAMEO.Manual.1.1b3.pdf
#
#     <h3> Filtering then to eliminate duplicated events to make index more accurate. </h3>
#
# </div>

# %%
golstein_dict = improved_scalar.to_dict(orient='records')
print(golstein_dict)
# Out:
# [{'event_code': 10, 'goldstein_scale': 0.0}, {'event_code': 11, 'goldstein_scale': -0.1}, {'event_code': 12, 'goldstein_scale': -0.4}, {'event_code': 13, 'goldstein_scale': 0.4}, {'event_code': 14, 'goldstein_scale': 0.0}, {'event_code': 15, 'goldstein_scale': 0.0}, {'event_code': 16, 'goldstein_scale': -2.0}, {'event_code': 17, 'goldstein_scale': 0.0}, {'event_code': 18, 'goldstein_scale': 3.4}, {'event_code': 19, 'goldstein_scale': 3.4}, {'event_code': 20, 'goldstein_scale': 3.0}, {'event_code': 21, 'goldstein_scale': 3.4}, {'event_code': 22, 'goldstein_scale': 3.2}, {'event_code': 23, 'goldstein_scale': 3.4}, {'event_code': 24, 'goldstein_scale': -0.3}, {'event_code': 25, 'goldstein_scale': -0.3}, {'event_code': 26, 'goldstein_scale': 4.0}, {'event_code': 27, 'goldstein_scale': 4.0}, {'event_code': 28, 'goldstein_scale': 4.0}, {'event_code': 30, 'goldstein_scale': 4.0}, {'event_code': 31, 'goldstein_scale': 5.2}, {'event_code': 32, 'goldstein_scale': 4.5}, {'event_code': 33, 'goldstein_scale': 5.2}, {'event_code': 34, 'goldstein_scale': 7.0}, {'event_code': 35, 'goldstein_scale': 7.0}, {'event_code': 36, 'goldstein_scale': 4.0}, {'event_code': 37, 'goldstein_scale': 5.0}, {'event_code': 38, 'goldstein_scale': 7.0}, {'event_code': 39, 'goldstein_scale': 5.0}, {'event_code': 40, 'goldstein_scale': 1.0}, {'event_code': 41, 'goldstein_scale': 1.0}, {'event_code': 42, 'goldstein_scale': 1.9}, {'event_code': 43, 'goldstein_scale': 2.8}, {'event_code': 44, 'goldstein_scale': 2.5}, {'event_code': 45, 'goldstein_scale': 5.0}, {'event_code': 46, 'goldstein_scale': 7.0}, {'event_code': 50, 'goldstein_scale': 3.5}, {'event_code': 51, 'goldstein_scale': 3.4}, {'event_code': 52, 'goldstein_scale': 3.5}, {'event_code': 53, 'goldstein_scale': 3.8}, {'event_code': 54, 'goldstein_scale': 6.0}, {'event_code': 55, 'goldstein_scale': 7.0}, {'event_code': 56, 'goldstein_scale': 7.0}, {'event_code': 57, 'goldstein_scale': 8.0}, {'event_code': 60, 'goldstein_scale': 6.0}, {'event_code': 61, 'goldstein_scale': 6.4}, {'event_code': 62, 'goldstein_scale': 7.4}, {'event_code': 63, 'goldstein_scale': 7.4}, {'event_code': 64, 'goldstein_scale': 7.0}, {'event_code': 70, 'goldstein_scale': 7.0}, {'event_code': 71, 'goldstein_scale': 7.4}, {'event_code': 72, 'goldstein_scale': 8.3}, {'event_code': 73, 'goldstein_scale': 7.4}, {'event_code': 74, 'goldstein_scale': 8.5}, {'event_code': 75, 'goldstein_scale': 7.0}, {'event_code': 80, 'goldstein_scale': 5.0}, {'event_code': 81, 'goldstein_scale': 5.0}, {'event_code': 82, 'goldstein_scale': 5.0}, {'event_code': 83, 'goldstein_scale': 5.0}, {'event_code': 84, 'goldstein_scale': 7.0}, {'event_code': 85, 'goldstein_scale': 7.0}, {'event_code': 86, 'goldstein_scale': 9.0}, {'event_code': 87, 'goldstein_scale': 9.0}, {'event_code': 90, 'goldstein_scale': -2.0}, {'event_code': 91, 'goldstein_scale': -2.0}, {'event_code': 92, 'goldstein_scale': -2.0}, {'event_code': 93, 'goldstein_scale': -2.0}, {'event_code': 100, 'goldstein_scale': -5.0}, {'event_code': 101, 'goldstein_scale': -5.0}, {'event_code': 102, 'goldstein_scale': -5.0}, {'event_code': 105, 'goldstein_scale': -5.0}, {'event_code': 106, 'goldstein_scale': -5.0}, {'event_code': 107, 'goldstein_scale': -5.0}, {'event_code': 110, 'goldstein_scale': -2.0}, {'event_code': 111, 'goldstein_scale': -2.0}, {'event_code': 112, 'goldstein_scale': -2.0}, {'event_code': 113, 'goldstein_scale': -2.0}, {'event_code': 114, 'goldstein_scale': -2.0}, {'event_code': 115, 'goldstein_scale': -2.0}, {'event_code': 116, 'goldstein_scale': -2.0}, {'event_code': 120, 'goldstein_scale': -4.0}, {'event_code': 121, 'goldstein_scale': -4.0}, {'event_code': 122, 'goldstein_scale': -4.0}, {'event_code': 124, 'goldstein_scale': -4.0}, {'event_code': 125, 'goldstein_scale': -5.0}, {'event_code': 127, 'goldstein_scale': -5.0}, {'event_code': 128, 'goldstein_scale': -5.0}, {'event_code': 129, 'goldstein_scale': -5.0}, {'event_code': 130, 'goldstein_scale': -4.4}, {'event_code': 131, 'goldstein ...

# %%
eds = eds[eds['is_root_event'] == 0]

eds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52741 entries, 2 to 135250
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   global_event_id  52741 non-null  int32
#  1   sqldate          52741 non-null  object
#  2   is_root_event    52741 non-null  int32
#  3   event_code       52741 non-null  int32
#  4   quad_class       52741 non-null  int32
#  5   goldstein_scale  52741 non-null  float64
#  6   num_mentions     52741 non-null  int32
#  7   num_articles     52741 non-null  int32
#  8   avg_tone         52741 non-null  float64
#  9   Country          52741 non-null  object
#  10  source_url       52741 non-null  object
# dtypes: float64(2), int32(6), object(3)
# memory usage: 3.6+ MB

# %%
eds.head(3)
# Out:
#    global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 2       1191508314  2023-08-09              0          71           2
# 3       1191508315  2023-08-09              0          71           2
# 4       1191508316  2023-08-09              0         141           3
#
#    goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 2              7.4             2             2 -6.618705      FJ
# 3              7.4             5             5 -6.618705      FJ
# 4             -6.5             1             1 -4.058442      IS
#
#                                                                                                               source_url
# 2              https://www.rnz.co.nz/international/pacific-news/524505/culture-hinders-fiji-s-human-trafficking-response
# 3              https://www.rnz.co.nz/international/pacific-news/524505/culture-hinders-fiji-s-human-trafficking-response
# 4  https://www.middleeasteye.net/news/canadian-mayor-opposed-pro-palestinian-protests-allowed-appoint-special-constables

# %%
eds.columns
# Out:
# Index(['global_event_id', 'sqldate', 'is_root_event', 'event_code',
#        'quad_class', 'goldstein_scale', 'num_mentions', 'num_articles',
#        'avg_tone', 'Country', 'source_url'],
#       dtype='object')

# %% [markdown]
# Checking Quad Class distribution
#
# QuadClass. (integer) The entire CAMEO event taxonomy is ultimately organized under four
# primary classifications: Verbal Cooperation, Material Cooperation, Verbal Conflict, and Material
# Conflict. This field specifies this primary classification for the event type, allowing analysis at the
# highest level of aggregation. The numeric codes in this field map to the Quad Classes as follows:
# 1=Verbal Cooperation, 2=Material Cooperation, 3=Verbal Conflict, 4=Material Conflict
# Source: http://data.gdeltproject.org/documentation/CAMEO.Manual.1.1b3.pdf
#
# - 1 and 2 are cooperations (positive)
# - 3 and 4 are conflicts    (negative)
# - 2 and 4 are more impactful in each category

# %%
eds['quad_class'].value_counts().sort_values(ascending=False)
# Out:
# quad_class
# 1    31795
# 4     7547
# 3     7541
# 2     5858
# Name: count, dtype: int64

# %% [markdown]
# For this day in particular there were about 50% more material conflicts than there were material cooperation events

# %%
eds.tail()
# Out:
#         global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 135246       1191708372  2024-08-08              0          20           1
# 135247       1191708373  2024-08-08              0          51           1
# 135248       1191708374  2024-08-08              0          51           1
# 135249       1191708375  2024-08-08              0          12           1
# 135250       1191708376  2024-08-08              0          20           1
#
#         goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 135246              3.0            10            10  1.433692      US
# 135247              3.4             4             4  1.416765      CA
# 135248              3.4             6             6  1.416765      CA
# 135249             -0.4            10            10 -2.985075      US
# 135250              3.0            10            10 -2.985075      US
#
#                                                                                                            source_url
# 135246            https://www.fcnl.org/updates/2024-08/native-boarding-school-report-tells-truth-doesnt-go-far-enough
# 135247  https://vancouversun.com:443/news/bc-health-experts-parents-battle-misinformation-about-gender-care-for-youth
# 135248  https://vancouversun.com:443/news/bc-health-experts-parents-battle-misinformation-about-gender-care-for-youth
# 135249                                                                 https://www.bbc.com/news/articles/clywwzzn14wo
# 135250                                                                 https://www.bbc.com/news/articles/clywwzzn14wo

# %%
new_eds = eds.sort_values(by=['goldstein_scale','num_articles'], ascending=False).reset_index()

new_eds.drop(columns=['index'], inplace=True)

new_eds
# Out:
#        global_event_id     sqldate  is_root_event  event_code  quad_class  \
# 0           1191520264  2024-08-08              0         874           2
# 1           1191622759  2024-08-08              0         874           2
# 2           1191595356  2023-08-09              0         874           2
# 3           1191619908  2024-08-08              0         874           2
# 4           1191603644  2024-08-08              0         874           2
# ...                ...         ...            ...         ...         ...
# 52736       1191707187  2024-08-08              0         190           4
# 52737       1191707188  2024-08-08              0         190           4
# 52738       1191707646  2024-08-08              0         190           4
# 52739       1191707647  2024-08-08              0         190           4
# 52740       1191707882  2024-08-08              0         190           4
#
#        goldstein_scale  num_mentions  num_articles  avg_tone Country  \
# 0                 10.0            90            90 -8.421541      NI
# 1                 10.0            64            64 -4.787869      US
# 2                 10.0            36            36 -0.420969      US
# 3                 10.0            30            30 -0.500731      US
# 4                 10.0            24            24 -3.418224      CH
# ...                ...           ...           ...       ...     ...
# 52736            -10.0             1             1 -3.352559      IZ
# 52737            -10.0             1             1 -3.352559      US
# 52738            -10.0             1             1 -7.305936      US
# 52739            -10.0             1             1 -7.305936      US
# 52740            -10.0             1             1 -3.238866      US
#
#                                                                                                                                                                       source_url
# 0                                                                           https://www.channelstv.com/2024/08/08/security-operatives-raid-nlc-headquarters-cart-away-documents/
# 1      https://www.news-gazette.com/news/nation-world/the-latest-debby-moves-inland-as-the-tropical-storm-soaks-south-carolina/article_cdd44870-9f8f-541d-bc3c-a020c21b20fe.html
# 2                                https://richmond.com/news/state-regional/government-politics/glenn-youngkin-election-security/article_a0cae04e-54f2-11ef-8ee5-ff80100b330b.html
# 3                                 https://www.daytondailynews.com/local/sen-brown-with-dayton-allies-hails-new-american-flag-law-at-air-force-museum/D5ONQFX3UNAKBF6KOMUGO3ZGYM/
# 4                                                                                  https://www.twincities.com/2024/08/08/bret-stephens-the-world-that-awaits-the-next-president/
# ...                                                                                                                                                                          ...
# 52736                                                                                              https://www.vulture.com/article/trap-is-good-and-so-is-m-night-shyamalan.html
# 52737                                                                                              https://www.vulture.com/article/trap-is-good-and-so-is-m-night-shyamalan.html
# 52738                                                                                            https://www.yahoo.com/news/clermont-county-woman-accused-killing-220805884.html
# 52739                                                                                            https://www.yahoo.com/news/clermont-county-woman-accused-killing-220805884.html
# 52740                                                               https://www.independent.co.uk/news/world/americas/columbia-unviersity-deans-resign-antisemitic-b2593651.html
#
# [52741 rows x 11 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - Thinking about this further, while Goldstein Scale is indeed useful per the latest data manipulations seems that Avg Tone can be more useful.
# - AvgTone. (numeric) This is the average “tone” of all documents containing one or more
# mentions of this event. The score ranges from -100 (extremely negative) to +100 (extremely
# positive). Common values range between -10 and +10, with 0 indicating neutral. This can be
# used as a method of filtering the “context” of events as a subtle measure of the importance of
# an event and as a proxy for the “impact” of that event. For example, a riot event with a slightly
# negative average tone is likely to have been a minor occurrence, whereas if it had an extremely
# negative average tone, it suggests a far more serious occurrence. A riot with a positive score
# likely suggests a very minor occurrence described in the context of a more positive narrative
# (such as a report of an attack occurring in a discussion of improving conditions on the ground in
# a country and how the number of attacks per day has been greatly reduced).
#     - Source: http://data.gdeltproject.org/documentation/CAMEO.Manual.1.1b3.pdf
#
#
#     <h3> So pivoting towards that as a key metric. </h3>
#
# </div>

# %%
# Check latest delta on these two variables:

num_mentions = eds['num_mentions'].sum()
num_articles = eds['num_articles'].sum()

print("Total num_mentions :", num_mentions)
print()
print("Total num_articles :",num_articles)
print()
print("Delta among num_mentions and num_articles is: ", num_mentions - num_articles)
print()
print("Delta percent among num_mentions and num_articles is: ", ((num_mentions - num_articles)/num_mentions)/100)
# Out:
# Total num_mentions : 444767
#
# Total num_articles : 436919
#
# Delta among num_mentions and num_articles is:  7848
#
# Delta percent among num_mentions and num_articles is:  0.0001764519400045417

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - This can be useful.
#
#     <h3> Much more needs to be computed. </h3>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <h2> Process Insights</h2>
# -------------------------------------------------------------------------------------------------------------------------------
#
# - EventCode is a very important column in Events Dataset as EventCode is the raw CAMEO action code describing the action
# - ...
#     - Source: http://data.gdeltproject.org/documentation/CAMEO.Manual.1.1b3.pdf
#
#     <h3> ... </h3>
#
# </div>

# %% [markdown]
# ## Note:
#
# ### Much more to be done.
#
# #### Continues at part II ...
