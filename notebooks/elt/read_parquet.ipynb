# %%
import pandas as pd
import pyarrow.parquet as pq


ruta_base = "/home/oscar/budasbi-repos/factored-datathon-2024-voyager/parquet"  # o "ruta/local/a/tus/archivos/"


df = pq.ParquetDataset(ruta_base, use_legacy_dataset=False).read_pandas().to_pandas()
# Out:
# /tmp/ipykernel_5957/179273696.py:8: FutureWarning: Passing 'use_legacy_dataset' is deprecated as of pyarrow 15.0.0 and will be removed in a future version.
#   df = pq.ParquetDataset(ruta_base, use_legacy_dataset=False).read_pandas().to_pandas()
#    numarts                      count_type  number   object_type  geo_type  \
# 0       54  CRISISLEX_C03_WELLBEING_HEALTH      19          None         1
# 1      431                            KILL       3         girls         4
# 2      431                            KILL       3         girls         4
# 3        1                           WOUND       2  IDF soldiers         1
# 4       33              CRISISLEX_T03_DEAD       6          None         1
#
#                         geo_fullname geo_country_code geo_adm1_code  geo_lat  \
# 0                             Israel               IS            IS  31.5000
# 1  Southport, Sefton, United Kingdom               UK          UKL8  53.6667
# ...

# %%
df.head()
# Out:
#    numarts                      count_type  number   object_type  geo_type  \
# 0       54  CRISISLEX_C03_WELLBEING_HEALTH      19          None         1
# 1      431                            KILL       3         girls         4
# 2      431                            KILL       3         girls         4
# 3        1                           WOUND       2  IDF soldiers         1
# 4       33              CRISISLEX_T03_DEAD       6          None         1
#
#                         geo_fullname geo_country_code geo_adm1_code  geo_lat  \
# 0                             Israel               IS            IS  31.5000
# 1  Southport, Sefton, United Kingdom               UK          UKL8  53.6667
# 2  Southport, Sefton, United Kingdom               UK          UKL8  53.6667
# 3                               Iran               IR            IR  32.0000
# 4                         Bangladesh               BG            BG  24.0000
#
#    geo_long geo_feature_id cameo_event_ids  \
# ...
